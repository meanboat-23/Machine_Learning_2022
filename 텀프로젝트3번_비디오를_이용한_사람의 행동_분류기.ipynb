# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/2022-ml-project5/sample_submission.csv
# /kaggle/input/2022-ml-project5/class_info.csv
# /kaggle/input/2022-ml-project5/train_label.csv
# /kaggle/input/2022-ml-project5/test/0261.avi
# /kaggle/input/2022-ml-project5/test/0435.avi
# /kaggle/input/2022-ml-project5/test/0309.avi
# /kaggle/input/2022-ml-project5/test/0039.avi
# /kaggle/input/2022-ml-project5/test/0162.avi
# /kaggle/input/2022-ml-project5/test/0402.avi
# /kaggle/input/2022-ml-project5/test/0255.avi
# /kaggle/input/2022-ml-project5/test/0416.avi
# /kaggle/input/2022-ml-project5/test/0354.avi
# /kaggle/input/2022-ml-project5/test/0486.avi
# /kaggle/input/2022-ml-project5/test/0113.avi
# /kaggle/input/2022-ml-project5/test/0106.avi
# /kaggle/input/2022-ml-project5/test/0291.avi
# /kaggle/input/2022-ml-project5/test/0407.avi
# /kaggle/input/2022-ml-project5/test/0247.avi
# /kaggle/input/2022-ml-project5/test/0442.avi
# /kaggle/input/2022-ml-project5/test/0193.avi
# /kaggle/input/2022-ml-project5/test/0044.avi
# /kaggle/input/2022-ml-project5/test/0136.avi
# /kaggle/input/2022-ml-project5/test/0332.avi
# /kaggle/input/2022-ml-project5/test/0311.avi
# /kaggle/input/2022-ml-project5/test/0386.avi
# /kaggle/input/2022-ml-project5/test/0476.avi
# /kaggle/input/2022-ml-project5/test/0464.avi
# /kaggle/input/2022-ml-project5/test/0204.avi
# /kaggle/input/2022-ml-project5/test/0346.avi
# /kaggle/input/2022-ml-project5/test/0326.avi
# /kaggle/input/2022-ml-project5/test/0056.avi
# /kaggle/input/2022-ml-project5/test/0462.avi
# /kaggle/input/2022-ml-project5/test/0130.avi
# /kaggle/input/2022-ml-project5/test/0349.avi
# /kaggle/input/2022-ml-project5/test/0240.avi
# /kaggle/input/2022-ml-project5/test/0037.avi
# /kaggle/input/2022-ml-project5/test/0088.avi
# /kaggle/input/2022-ml-project5/test/0196.avi
# /kaggle/input/2022-ml-project5/test/0208.avi
# /kaggle/input/2022-ml-project5/test/0269.avi
# /kaggle/input/2022-ml-project5/test/0496.avi
# /kaggle/input/2022-ml-project5/test/0267.avi
# /kaggle/input/2022-ml-project5/test/0188.avi
# /kaggle/input/2022-ml-project5/test/0275.avi
# /kaggle/input/2022-ml-project5/test/0359.avi
# /kaggle/input/2022-ml-project5/test/0074.avi
# /kaggle/input/2022-ml-project5/test/0362.avi
# /kaggle/input/2022-ml-project5/test/0243.avi
# /kaggle/input/2022-ml-project5/test/0413.avi
# /kaggle/input/2022-ml-project5/test/0499.avi
# /kaggle/input/2022-ml-project5/test/0177.avi
# /kaggle/input/2022-ml-project5/test/0250.avi
# /kaggle/input/2022-ml-project5/test/0093.avi
# /kaggle/input/2022-ml-project5/test/0465.avi
# /kaggle/input/2022-ml-project5/test/0098.avi
# /kaggle/input/2022-ml-project5/test/0057.avi
# /kaggle/input/2022-ml-project5/test/0114.avi
# /kaggle/input/2022-ml-project5/test/0210.avi
# /kaggle/input/2022-ml-project5/test/0433.avi
# /kaggle/input/2022-ml-project5/test/0378.avi
# /kaggle/input/2022-ml-project5/test/0405.avi
# /kaggle/input/2022-ml-project5/test/0373.avi
# /kaggle/input/2022-ml-project5/test/0324.avi
# /kaggle/input/2022-ml-project5/test/0375.avi
# /kaggle/input/2022-ml-project5/test/0097.avi
# /kaggle/input/2022-ml-project5/test/0067.avi
# /kaggle/input/2022-ml-project5/test/0118.avi
# /kaggle/input/2022-ml-project5/test/0383.avi
# /kaggle/input/2022-ml-project5/test/0091.avi
# /kaggle/input/2022-ml-project5/test/0080.avi
# /kaggle/input/2022-ml-project5/test/0090.avi
# /kaggle/input/2022-ml-project5/test/0436.avi
# /kaggle/input/2022-ml-project5/test/0047.avi
# /kaggle/input/2022-ml-project5/test/0132.avi
# /kaggle/input/2022-ml-project5/test/0449.avi
# /kaggle/input/2022-ml-project5/test/0122.avi
# /kaggle/input/2022-ml-project5/test/0503.avi
# /kaggle/input/2022-ml-project5/test/0096.avi
# /kaggle/input/2022-ml-project5/test/0238.avi
# /kaggle/input/2022-ml-project5/test/0225.avi
# /kaggle/input/2022-ml-project5/test/0185.avi
# /kaggle/input/2022-ml-project5/test/0477.avi
# /kaggle/input/2022-ml-project5/test/0139.avi
# /kaggle/input/2022-ml-project5/test/0222.avi
# /kaggle/input/2022-ml-project5/test/0294.avi
# /kaggle/input/2022-ml-project5/test/0257.avi
# /kaggle/input/2022-ml-project5/test/0123.avi
# /kaggle/input/2022-ml-project5/test/0181.avi
# /kaggle/input/2022-ml-project5/test/0200.avi
# /kaggle/input/2022-ml-project5/test/0494.avi
# /kaggle/input/2022-ml-project5/test/0095.avi
# /kaggle/input/2022-ml-project5/test/0498.avi
# /kaggle/input/2022-ml-project5/test/0382.avi
# /kaggle/input/2022-ml-project5/test/0108.avi
# /kaggle/input/2022-ml-project5/test/0194.avi
# /kaggle/input/2022-ml-project5/test/0046.avi
# /kaggle/input/2022-ml-project5/test/0217.avi
# /kaggle/input/2022-ml-project5/test/0374.avi
# /kaggle/input/2022-ml-project5/test/0010.avi
# /kaggle/input/2022-ml-project5/test/0335.avi
# /kaggle/input/2022-ml-project5/test/0392.avi
# /kaggle/input/2022-ml-project5/test/0463.avi
# /kaggle/input/2022-ml-project5/test/0062.avi
# /kaggle/input/2022-ml-project5/test/0385.avi
# /kaggle/input/2022-ml-project5/test/0171.avi
# /kaggle/input/2022-ml-project5/test/0124.avi
# /kaggle/input/2022-ml-project5/test/0389.avi
# /kaggle/input/2022-ml-project5/test/0148.avi
# /kaggle/input/2022-ml-project5/test/0415.avi
# /kaggle/input/2022-ml-project5/test/0271.avi
# /kaggle/input/2022-ml-project5/test/0495.avi
# /kaggle/input/2022-ml-project5/test/0393.avi
# /kaggle/input/2022-ml-project5/test/0356.avi
# /kaggle/input/2022-ml-project5/test/0024.avi
# /kaggle/input/2022-ml-project5/test/0228.avi
# /kaggle/input/2022-ml-project5/test/0478.avi
# /kaggle/input/2022-ml-project5/test/0409.avi
# /kaggle/input/2022-ml-project5/test/0282.avi
# /kaggle/input/2022-ml-project5/test/0376.avi
# /kaggle/input/2022-ml-project5/test/0418.avi
# /kaggle/input/2022-ml-project5/test/0134.avi
# /kaggle/input/2022-ml-project5/test/0234.avi
# /kaggle/input/2022-ml-project5/test/0094.avi
# /kaggle/input/2022-ml-project5/test/0187.avi
# /kaggle/input/2022-ml-project5/test/0322.avi
# /kaggle/input/2022-ml-project5/test/0165.avi
# /kaggle/input/2022-ml-project5/test/0388.avi
# /kaggle/input/2022-ml-project5/test/0141.avi
# /kaggle/input/2022-ml-project5/test/0076.avi
# /kaggle/input/2022-ml-project5/test/0453.avi
# /kaggle/input/2022-ml-project5/test/0302.avi
# /kaggle/input/2022-ml-project5/test/0381.avi
# /kaggle/input/2022-ml-project5/test/0367.avi
# /kaggle/input/2022-ml-project5/test/0191.avi
# /kaggle/input/2022-ml-project5/test/0338.avi
# /kaggle/input/2022-ml-project5/test/0031.avi
# /kaggle/input/2022-ml-project5/test/0125.avi
# /kaggle/input/2022-ml-project5/test/0396.avi
# /kaggle/input/2022-ml-project5/test/0321.avi
# /kaggle/input/2022-ml-project5/test/0281.avi
# /kaggle/input/2022-ml-project5/test/0353.avi
# /kaggle/input/2022-ml-project5/test/0241.avi
# /kaggle/input/2022-ml-project5/test/0488.avi
# /kaggle/input/2022-ml-project5/test/0161.avi
# /kaggle/input/2022-ml-project5/test/0129.avi
# /kaggle/input/2022-ml-project5/test/0259.avi
# /kaggle/input/2022-ml-project5/test/0260.avi
# /kaggle/input/2022-ml-project5/test/0115.avi
# /kaggle/input/2022-ml-project5/test/0485.avi
# /kaggle/input/2022-ml-project5/test/0054.avi
# /kaggle/input/2022-ml-project5/test/0011.avi
# /kaggle/input/2022-ml-project5/test/0143.avi
# /kaggle/input/2022-ml-project5/test/0384.avi
# /kaggle/input/2022-ml-project5/test/0159.avi
# /kaggle/input/2022-ml-project5/test/0154.avi
# /kaggle/input/2022-ml-project5/test/0040.avi
# /kaggle/input/2022-ml-project5/test/0025.avi
# /kaggle/input/2022-ml-project5/test/0372.avi
# /kaggle/input/2022-ml-project5/test/0364.avi
# /kaggle/input/2022-ml-project5/test/0366.avi
# /kaggle/input/2022-ml-project5/test/0100.avi
# /kaggle/input/2022-ml-project5/test/0268.avi
# /kaggle/input/2022-ml-project5/test/0369.avi
# /kaggle/input/2022-ml-project5/test/0480.avi
# /kaggle/input/2022-ml-project5/test/0052.avi
# /kaggle/input/2022-ml-project5/test/0455.avi
# /kaggle/input/2022-ml-project5/test/0003.avi
# /kaggle/input/2022-ml-project5/test/0298.avi
# /kaggle/input/2022-ml-project5/test/0027.avi
# /kaggle/input/2022-ml-project5/test/0434.avi
# /kaggle/input/2022-ml-project5/test/0167.avi
# /kaggle/input/2022-ml-project5/test/0008.avi
# /kaggle/input/2022-ml-project5/test/0142.avi
# /kaggle/input/2022-ml-project5/test/0417.avi
# /kaggle/input/2022-ml-project5/test/0145.avi
# /kaggle/input/2022-ml-project5/test/0348.avi
# /kaggle/input/2022-ml-project5/test/0414.avi
# /kaggle/input/2022-ml-project5/test/0336.avi
# /kaggle/input/2022-ml-project5/test/0163.avi
# /kaggle/input/2022-ml-project5/test/0452.avi
# /kaggle/input/2022-ml-project5/test/0157.avi
# /kaggle/input/2022-ml-project5/test/0001.avi
# /kaggle/input/2022-ml-project5/test/0155.avi
# /kaggle/input/2022-ml-project5/test/0233.avi
# /kaggle/input/2022-ml-project5/test/0223.avi
# /kaggle/input/2022-ml-project5/test/0300.avi
# /kaggle/input/2022-ml-project5/test/0146.avi
# /kaggle/input/2022-ml-project5/test/0447.avi
# /kaggle/input/2022-ml-project5/test/0012.avi
# /kaggle/input/2022-ml-project5/test/0184.avi
# /kaggle/input/2022-ml-project5/test/0256.avi
# /kaggle/input/2022-ml-project5/test/0128.avi
# /kaggle/input/2022-ml-project5/test/0445.avi
# /kaggle/input/2022-ml-project5/test/0448.avi
# /kaggle/input/2022-ml-project5/test/0397.avi
# /kaggle/input/2022-ml-project5/test/0214.avi
# /kaggle/input/2022-ml-project5/test/0399.avi
# /kaggle/input/2022-ml-project5/test/0361.avi
# /kaggle/input/2022-ml-project5/test/0215.avi
# /kaggle/input/2022-ml-project5/test/0440.avi
# /kaggle/input/2022-ml-project5/test/0472.avi
# /kaggle/input/2022-ml-project5/test/0066.avi
# /kaggle/input/2022-ml-project5/test/0104.avi
# /kaggle/input/2022-ml-project5/test/0398.avi
# /kaggle/input/2022-ml-project5/test/0016.avi
# /kaggle/input/2022-ml-project5/test/0263.avi
# /kaggle/input/2022-ml-project5/test/0174.avi
# /kaggle/input/2022-ml-project5/test/0347.avi
# /kaggle/input/2022-ml-project5/test/0325.avi
# /kaggle/input/2022-ml-project5/test/0077.avi
# /kaggle/input/2022-ml-project5/test/0481.avi
# /kaggle/input/2022-ml-project5/test/0135.avi
# /kaggle/input/2022-ml-project5/test/0169.avi
# /kaggle/input/2022-ml-project5/test/0211.avi
# /kaggle/input/2022-ml-project5/test/0197.avi
# /kaggle/input/2022-ml-project5/test/0333.avi
# /kaggle/input/2022-ml-project5/test/0007.avi
# /kaggle/input/2022-ml-project5/test/0301.avi
# /kaggle/input/2022-ml-project5/test/0429.avi
# /kaggle/input/2022-ml-project5/test/0307.avi
# /kaggle/input/2022-ml-project5/test/0116.avi
# /kaggle/input/2022-ml-project5/test/0170.avi
# /kaggle/input/2022-ml-project5/test/0444.avi
# /kaggle/input/2022-ml-project5/test/0075.avi
# /kaggle/input/2022-ml-project5/test/0013.avi
# /kaggle/input/2022-ml-project5/test/0479.avi
# /kaggle/input/2022-ml-project5/test/0313.avi
# /kaggle/input/2022-ml-project5/test/0232.avi
# /kaggle/input/2022-ml-project5/test/0420.avi
# /kaggle/input/2022-ml-project5/test/0387.avi
# /kaggle/input/2022-ml-project5/test/0286.avi
# /kaggle/input/2022-ml-project5/test/0176.avi
# /kaggle/input/2022-ml-project5/test/0368.avi
# /kaggle/input/2022-ml-project5/test/0036.avi
# /kaggle/input/2022-ml-project5/test/0244.avi
# /kaggle/input/2022-ml-project5/test/0454.avi
# /kaggle/input/2022-ml-project5/test/0219.avi
# /kaggle/input/2022-ml-project5/test/0026.avi
# /kaggle/input/2022-ml-project5/test/0483.avi
# /kaggle/input/2022-ml-project5/test/0430.avi
# /kaggle/input/2022-ml-project5/test/0248.avi
# /kaggle/input/2022-ml-project5/test/0150.avi
# /kaggle/input/2022-ml-project5/test/0446.avi
# /kaggle/input/2022-ml-project5/test/0285.avi
# /kaggle/input/2022-ml-project5/test/0189.avi
# /kaggle/input/2022-ml-project5/test/0239.avi
# /kaggle/input/2022-ml-project5/test/0105.avi
# /kaggle/input/2022-ml-project5/test/0068.avi
# /kaggle/input/2022-ml-project5/test/0330.avi
# /kaggle/input/2022-ml-project5/test/0439.avi
# /kaggle/input/2022-ml-project5/test/0183.avi
# /kaggle/input/2022-ml-project5/test/0195.avi
# /kaggle/input/2022-ml-project5/test/0081.avi
# /kaggle/input/2022-ml-project5/test/0306.avi
# /kaggle/input/2022-ml-project5/test/0131.avi
# /kaggle/input/2022-ml-project5/test/0226.avi
# /kaggle/input/2022-ml-project5/test/0441.avi
# /kaggle/input/2022-ml-project5/test/0102.avi
# /kaggle/input/2022-ml-project5/test/0050.avi
# /kaggle/input/2022-ml-project5/test/0043.avi
# /kaggle/input/2022-ml-project5/test/0316.avi
# /kaggle/input/2022-ml-project5/test/0410.avi
# /kaggle/input/2022-ml-project5/test/0422.avi
# /kaggle/input/2022-ml-project5/test/0084.avi
# /kaggle/input/2022-ml-project5/test/0427.avi
# /kaggle/input/2022-ml-project5/test/0458.avi
# /kaggle/input/2022-ml-project5/test/0265.avi
# /kaggle/input/2022-ml-project5/test/0252.avi
# /kaggle/input/2022-ml-project5/test/0206.avi
# /kaggle/input/2022-ml-project5/test/0002.avi
# /kaggle/input/2022-ml-project5/test/0363.avi
# /kaggle/input/2022-ml-project5/test/0502.avi
# /kaggle/input/2022-ml-project5/test/0071.avi
# /kaggle/input/2022-ml-project5/test/0212.avi
# /kaggle/input/2022-ml-project5/test/0264.avi
# /kaggle/input/2022-ml-project5/test/0018.avi
# /kaggle/input/2022-ml-project5/test/0395.avi
# /kaggle/input/2022-ml-project5/test/0467.avi
# /kaggle/input/2022-ml-project5/test/0048.avi
# /kaggle/input/2022-ml-project5/test/0466.avi
# /kaggle/input/2022-ml-project5/test/0042.avi
# /kaggle/input/2022-ml-project5/test/0049.avi
# /kaggle/input/2022-ml-project5/test/0087.avi
# /kaggle/input/2022-ml-project5/test/0173.avi
# /kaggle/input/2022-ml-project5/test/0107.avi
# /kaggle/input/2022-ml-project5/test/0205.avi
# /kaggle/input/2022-ml-project5/test/0041.avi
# /kaggle/input/2022-ml-project5/test/0072.avi
# /kaggle/input/2022-ml-project5/test/0083.avi
# /kaggle/input/2022-ml-project5/test/0491.avi
# /kaggle/input/2022-ml-project5/test/0357.avi
# /kaggle/input/2022-ml-project5/test/0304.avi
# /kaggle/input/2022-ml-project5/test/0064.avi
# /kaggle/input/2022-ml-project5/test/0419.avi
# /kaggle/input/2022-ml-project5/test/0504.avi
# /kaggle/input/2022-ml-project5/test/0342.avi
# /kaggle/input/2022-ml-project5/test/0319.avi
# /kaggle/input/2022-ml-project5/test/0028.avi
# /kaggle/input/2022-ml-project5/test/0246.avi
# /kaggle/input/2022-ml-project5/test/0266.avi
# /kaggle/input/2022-ml-project5/test/0229.avi
# /kaggle/input/2022-ml-project5/test/0190.avi
# /kaggle/input/2022-ml-project5/test/0500.avi
# /kaggle/input/2022-ml-project5/test/0149.avi
# /kaggle/input/2022-ml-project5/test/0380.avi
# /kaggle/input/2022-ml-project5/test/0133.avi
# /kaggle/input/2022-ml-project5/test/0055.avi
# /kaggle/input/2022-ml-project5/test/0343.avi
# /kaggle/input/2022-ml-project5/test/0428.avi
# /kaggle/input/2022-ml-project5/test/0351.avi
# /kaggle/input/2022-ml-project5/test/0280.avi
# /kaggle/input/2022-ml-project5/test/0475.avi
# /kaggle/input/2022-ml-project5/test/0006.avi
# /kaggle/input/2022-ml-project5/test/0450.avi
# /kaggle/input/2022-ml-project5/test/0151.avi
# /kaggle/input/2022-ml-project5/test/0179.avi
# /kaggle/input/2022-ml-project5/test/0005.avi
# /kaggle/input/2022-ml-project5/test/0022.avi
# /kaggle/input/2022-ml-project5/test/0474.avi
# /kaggle/input/2022-ml-project5/test/0089.avi
# /kaggle/input/2022-ml-project5/test/0178.avi
# /kaggle/input/2022-ml-project5/test/0144.avi
# /kaggle/input/2022-ml-project5/test/0262.avi
# /kaggle/input/2022-ml-project5/test/0482.avi
# /kaggle/input/2022-ml-project5/test/0394.avi
# /kaggle/input/2022-ml-project5/test/0468.avi
# /kaggle/input/2022-ml-project5/test/0497.avi
# /kaggle/input/2022-ml-project5/test/0112.avi
# /kaggle/input/2022-ml-project5/test/0035.avi
# /kaggle/input/2022-ml-project5/test/0317.avi
# /kaggle/input/2022-ml-project5/test/0045.avi
# /kaggle/input/2022-ml-project5/test/0426.avi
# /kaggle/input/2022-ml-project5/test/0126.avi
# /kaggle/input/2022-ml-project5/test/0408.avi
# /kaggle/input/2022-ml-project5/test/0152.avi
# /kaggle/input/2022-ml-project5/test/0270.avi
# /kaggle/input/2022-ml-project5/test/0352.avi
# /kaggle/input/2022-ml-project5/test/0272.avi
# /kaggle/input/2022-ml-project5/test/0489.avi
# /kaggle/input/2022-ml-project5/test/0345.avi
# /kaggle/input/2022-ml-project5/test/0438.avi
# /kaggle/input/2022-ml-project5/test/0213.avi
# /kaggle/input/2022-ml-project5/test/0103.avi
# /kaggle/input/2022-ml-project5/test/0253.avi
# /kaggle/input/2022-ml-project5/test/0117.avi
# /kaggle/input/2022-ml-project5/test/0484.avi
# /kaggle/input/2022-ml-project5/test/0147.avi
# /kaggle/input/2022-ml-project5/test/0473.avi
# /kaggle/input/2022-ml-project5/test/0017.avi
# /kaggle/input/2022-ml-project5/test/0140.avi
# /kaggle/input/2022-ml-project5/test/0109.avi
# /kaggle/input/2022-ml-project5/test/0004.avi
# /kaggle/input/2022-ml-project5/test/0401.avi
# /kaggle/input/2022-ml-project5/test/0339.avi
# /kaggle/input/2022-ml-project5/test/0236.avi
# /kaggle/input/2022-ml-project5/test/0119.avi
# /kaggle/input/2022-ml-project5/test/0166.avi
# /kaggle/input/2022-ml-project5/test/0279.avi
# /kaggle/input/2022-ml-project5/test/0379.avi
# /kaggle/input/2022-ml-project5/test/0065.avi
# /kaggle/input/2022-ml-project5/test/0274.avi
# /kaggle/input/2022-ml-project5/test/0058.avi
# /kaggle/input/2022-ml-project5/test/0032.avi
# /kaggle/input/2022-ml-project5/test/0278.avi
# /kaggle/input/2022-ml-project5/test/0021.avi
# /kaggle/input/2022-ml-project5/test/0051.avi
# /kaggle/input/2022-ml-project5/test/0258.avi
# /kaggle/input/2022-ml-project5/test/0370.avi
# /kaggle/input/2022-ml-project5/test/0490.avi
# /kaggle/input/2022-ml-project5/test/0023.avi
# /kaggle/input/2022-ml-project5/test/0461.avi
# /kaggle/input/2022-ml-project5/test/0431.avi
# /kaggle/input/2022-ml-project5/test/0443.avi
# /kaggle/input/2022-ml-project5/test/0086.avi
# /kaggle/input/2022-ml-project5/test/0120.avi
# /kaggle/input/2022-ml-project5/test/0137.avi
# /kaggle/input/2022-ml-project5/test/0323.avi
# /kaggle/input/2022-ml-project5/test/0015.avi
# /kaggle/input/2022-ml-project5/test/0360.avi
# /kaggle/input/2022-ml-project5/test/0099.avi
# /kaggle/input/2022-ml-project5/test/0404.avi
# /kaggle/input/2022-ml-project5/test/0283.avi
# /kaggle/input/2022-ml-project5/test/0198.avi
# /kaggle/input/2022-ml-project5/test/0318.avi
# /kaggle/input/2022-ml-project5/test/0199.avi
# /kaggle/input/2022-ml-project5/test/0230.avi
# /kaggle/input/2022-ml-project5/test/0299.avi
# /kaggle/input/2022-ml-project5/test/0295.avi
# /kaggle/input/2022-ml-project5/test/0331.avi
# /kaggle/input/2022-ml-project5/test/0391.avi
# /kaggle/input/2022-ml-project5/test/0358.avi
# /kaggle/input/2022-ml-project5/test/0224.avi
# /kaggle/input/2022-ml-project5/test/0457.avi
# /kaggle/input/2022-ml-project5/test/0493.avi
# /kaggle/input/2022-ml-project5/test/0400.avi
# /kaggle/input/2022-ml-project5/test/0314.avi
# /kaggle/input/2022-ml-project5/test/0320.avi
# /kaggle/input/2022-ml-project5/test/0160.avi
# /kaggle/input/2022-ml-project5/test/0000.avi
# /kaggle/input/2022-ml-project5/test/0168.avi
# /kaggle/input/2022-ml-project5/test/0202.avi
# /kaggle/input/2022-ml-project5/test/0328.avi
# /kaggle/input/2022-ml-project5/test/0469.avi
# /kaggle/input/2022-ml-project5/test/0403.avi
# /kaggle/input/2022-ml-project5/test/0078.avi
# /kaggle/input/2022-ml-project5/test/0009.avi
# /kaggle/input/2022-ml-project5/test/0289.avi
# /kaggle/input/2022-ml-project5/test/0312.avi
# /kaggle/input/2022-ml-project5/test/0053.avi
# /kaggle/input/2022-ml-project5/test/0203.avi
# /kaggle/input/2022-ml-project5/test/0371.avi
# /kaggle/input/2022-ml-project5/test/0365.avi
# /kaggle/input/2022-ml-project5/test/0273.avi
# /kaggle/input/2022-ml-project5/test/0327.avi
# /kaggle/input/2022-ml-project5/test/0459.avi
# /kaggle/input/2022-ml-project5/test/0340.avi
# /kaggle/input/2022-ml-project5/test/0218.avi
# /kaggle/input/2022-ml-project5/test/0425.avi
# /kaggle/input/2022-ml-project5/test/0254.avi
# /kaggle/input/2022-ml-project5/test/0296.avi
# /kaggle/input/2022-ml-project5/test/0063.avi
# /kaggle/input/2022-ml-project5/test/0061.avi
# /kaggle/input/2022-ml-project5/test/0487.avi
# /kaggle/input/2022-ml-project5/test/0127.avi
# /kaggle/input/2022-ml-project5/test/0029.avi
# /kaggle/input/2022-ml-project5/test/0492.avi
# /kaggle/input/2022-ml-project5/test/0182.avi
# /kaggle/input/2022-ml-project5/test/0341.avi
# /kaggle/input/2022-ml-project5/test/0350.avi
# /kaggle/input/2022-ml-project5/test/0079.avi
# /kaggle/input/2022-ml-project5/test/0288.avi
# /kaggle/input/2022-ml-project5/test/0277.avi
# /kaggle/input/2022-ml-project5/test/0180.avi
# /kaggle/input/2022-ml-project5/test/0284.avi
# /kaggle/input/2022-ml-project5/test/0110.avi
# /kaggle/input/2022-ml-project5/test/0242.avi
# /kaggle/input/2022-ml-project5/test/0305.avi
# /kaggle/input/2022-ml-project5/test/0470.avi
# /kaggle/input/2022-ml-project5/test/0227.avi
# /kaggle/input/2022-ml-project5/test/0315.avi
# /kaggle/input/2022-ml-project5/test/0456.avi
# /kaggle/input/2022-ml-project5/test/0172.avi
# /kaggle/input/2022-ml-project5/test/0175.avi
# /kaggle/input/2022-ml-project5/test/0251.avi
# /kaggle/input/2022-ml-project5/test/0034.avi
# /kaggle/input/2022-ml-project5/test/0424.avi
# /kaggle/input/2022-ml-project5/test/0085.avi
# /kaggle/input/2022-ml-project5/test/0101.avi
# /kaggle/input/2022-ml-project5/test/0308.avi
# /kaggle/input/2022-ml-project5/test/0249.avi
# /kaggle/input/2022-ml-project5/test/0412.avi
# /kaggle/input/2022-ml-project5/test/0070.avi
# /kaggle/input/2022-ml-project5/test/0411.avi
# /kaggle/input/2022-ml-project5/test/0073.avi
# /kaggle/input/2022-ml-project5/test/0192.avi
# /kaggle/input/2022-ml-project5/test/0276.avi
# /kaggle/input/2022-ml-project5/test/0437.avi
# /kaggle/input/2022-ml-project5/test/0209.avi
# /kaggle/input/2022-ml-project5/test/0297.avi
# /kaggle/input/2022-ml-project5/test/0501.avi
# /kaggle/input/2022-ml-project5/test/0334.avi
# /kaggle/input/2022-ml-project5/test/0153.avi
# /kaggle/input/2022-ml-project5/test/0421.avi
# /kaggle/input/2022-ml-project5/test/0030.avi
# /kaggle/input/2022-ml-project5/test/0337.avi
# /kaggle/input/2022-ml-project5/test/0293.avi
# /kaggle/input/2022-ml-project5/test/0201.avi
# /kaggle/input/2022-ml-project5/test/0220.avi
# /kaggle/input/2022-ml-project5/test/0231.avi
# /kaggle/input/2022-ml-project5/test/0292.avi
# /kaggle/input/2022-ml-project5/test/0164.avi
# /kaggle/input/2022-ml-project5/test/0221.avi
# /kaggle/input/2022-ml-project5/test/0060.avi
# /kaggle/input/2022-ml-project5/test/0038.avi
# /kaggle/input/2022-ml-project5/test/0111.avi
# /kaggle/input/2022-ml-project5/test/0069.avi
# /kaggle/input/2022-ml-project5/test/0207.avi
# /kaggle/input/2022-ml-project5/test/0287.avi
# /kaggle/input/2022-ml-project5/test/0290.avi
# /kaggle/input/2022-ml-project5/test/0092.avi
# /kaggle/input/2022-ml-project5/test/0235.avi
# /kaggle/input/2022-ml-project5/test/0460.avi
# /kaggle/input/2022-ml-project5/test/0059.avi
# /kaggle/input/2022-ml-project5/test/0158.avi
# /kaggle/input/2022-ml-project5/test/0014.avi
# /kaggle/input/2022-ml-project5/test/0451.avi
# /kaggle/input/2022-ml-project5/test/0245.avi
# /kaggle/input/2022-ml-project5/test/0355.avi
# /kaggle/input/2022-ml-project5/test/0156.avi
# /kaggle/input/2022-ml-project5/test/0471.avi
# /kaggle/input/2022-ml-project5/test/0186.avi
# /kaggle/input/2022-ml-project5/test/0329.avi
# /kaggle/input/2022-ml-project5/test/0237.avi
# /kaggle/input/2022-ml-project5/test/0423.avi
# /kaggle/input/2022-ml-project5/test/0432.avi
# /kaggle/input/2022-ml-project5/test/0033.avi
# /kaggle/input/2022-ml-project5/test/0344.avi
# /kaggle/input/2022-ml-project5/test/0138.avi
# /kaggle/input/2022-ml-project5/test/0082.avi
# /kaggle/input/2022-ml-project5/test/0216.avi
# /kaggle/input/2022-ml-project5/test/0121.avi
# /kaggle/input/2022-ml-project5/test/0377.avi
# /kaggle/input/2022-ml-project5/test/0406.avi
# /kaggle/input/2022-ml-project5/test/0019.avi
# /kaggle/input/2022-ml-project5/test/0020.avi
# /kaggle/input/2022-ml-project5/test/0390.avi
# /kaggle/input/2022-ml-project5/test/0303.avi
# /kaggle/input/2022-ml-project5/test/0310.avi
# /kaggle/input/2022-ml-project5/train/0261.avi
# /kaggle/input/2022-ml-project5/train/1266.avi
# /kaggle/input/2022-ml-project5/train/1560.avi
# /kaggle/input/2022-ml-project5/train/0589.avi
# /kaggle/input/2022-ml-project5/train/1316.avi
# /kaggle/input/2022-ml-project5/train/0933.avi
# /kaggle/input/2022-ml-project5/train/0435.avi
# /kaggle/input/2022-ml-project5/train/1612.avi
# /kaggle/input/2022-ml-project5/train/1367.avi
# /kaggle/input/2022-ml-project5/train/1828.avi
# /kaggle/input/2022-ml-project5/train/0586.avi
# /kaggle/input/2022-ml-project5/train/1582.avi
# /kaggle/input/2022-ml-project5/train/1530.avi
# /kaggle/input/2022-ml-project5/train/1220.avi
# /kaggle/input/2022-ml-project5/train/0309.avi
# /kaggle/input/2022-ml-project5/train/1245.avi
# /kaggle/input/2022-ml-project5/train/0737.avi
# /kaggle/input/2022-ml-project5/train/1834.avi
# /kaggle/input/2022-ml-project5/train/0632.avi
# /kaggle/input/2022-ml-project5/train/1882.avi
# /kaggle/input/2022-ml-project5/train/0944.avi
# /kaggle/input/2022-ml-project5/train/0039.avi
# /kaggle/input/2022-ml-project5/train/1672.avi
# /kaggle/input/2022-ml-project5/train/1700.avi
# /kaggle/input/2022-ml-project5/train/0753.avi
# /kaggle/input/2022-ml-project5/train/0162.avi
# /kaggle/input/2022-ml-project5/train/1614.avi
# /kaggle/input/2022-ml-project5/train/0402.avi
# /kaggle/input/2022-ml-project5/train/1824.avi
# /kaggle/input/2022-ml-project5/train/1930.avi
# /kaggle/input/2022-ml-project5/train/1476.avi
# /kaggle/input/2022-ml-project5/train/0255.avi
# /kaggle/input/2022-ml-project5/train/0416.avi
# /kaggle/input/2022-ml-project5/train/0948.avi
# /kaggle/input/2022-ml-project5/train/0354.avi
# /kaggle/input/2022-ml-project5/train/1850.avi
# /kaggle/input/2022-ml-project5/train/0538.avi
# /kaggle/input/2022-ml-project5/train/0486.avi
# /kaggle/input/2022-ml-project5/train/0113.avi
# /kaggle/input/2022-ml-project5/train/0568.avi
# /kaggle/input/2022-ml-project5/train/0106.avi
# /kaggle/input/2022-ml-project5/train/1438.avi
# /kaggle/input/2022-ml-project5/train/1926.avi
# /kaggle/input/2022-ml-project5/train/0853.avi
# /kaggle/input/2022-ml-project5/train/1261.avi
# /kaggle/input/2022-ml-project5/train/1830.avi
# /kaggle/input/2022-ml-project5/train/1021.avi
# /kaggle/input/2022-ml-project5/train/1809.avi
# /kaggle/input/2022-ml-project5/train/1617.avi
# /kaggle/input/2022-ml-project5/train/1532.avi
# /kaggle/input/2022-ml-project5/train/0546.avi
# /kaggle/input/2022-ml-project5/train/1802.avi
# /kaggle/input/2022-ml-project5/train/0291.avi
# /kaggle/input/2022-ml-project5/train/0407.avi
# /kaggle/input/2022-ml-project5/train/1490.avi
# /kaggle/input/2022-ml-project5/train/0247.avi
# /kaggle/input/2022-ml-project5/train/1103.avi
# /kaggle/input/2022-ml-project5/train/0442.avi
# /kaggle/input/2022-ml-project5/train/0894.avi
# /kaggle/input/2022-ml-project5/train/1744.avi
# /kaggle/input/2022-ml-project5/train/1401.avi
# /kaggle/input/2022-ml-project5/train/1577.avi
# /kaggle/input/2022-ml-project5/train/1980.avi
# /kaggle/input/2022-ml-project5/train/1825.avi
# /kaggle/input/2022-ml-project5/train/1300.avi
# /kaggle/input/2022-ml-project5/train/1329.avi
# /kaggle/input/2022-ml-project5/train/1934.avi
# /kaggle/input/2022-ml-project5/train/0728.avi
# /kaggle/input/2022-ml-project5/train/0193.avi
# /kaggle/input/2022-ml-project5/train/0644.avi
# /kaggle/input/2022-ml-project5/train/1015.avi
# /kaggle/input/2022-ml-project5/train/1994.avi
# /kaggle/input/2022-ml-project5/train/0044.avi
# /kaggle/input/2022-ml-project5/train/0136.avi
# /kaggle/input/2022-ml-project5/train/0332.avi
# /kaggle/input/2022-ml-project5/train/0775.avi
# /kaggle/input/2022-ml-project5/train/0311.avi
# /kaggle/input/2022-ml-project5/train/0386.avi
# /kaggle/input/2022-ml-project5/train/1889.avi
# /kaggle/input/2022-ml-project5/train/1076.avi
# /kaggle/input/2022-ml-project5/train/0476.avi
# /kaggle/input/2022-ml-project5/train/1234.avi
# /kaggle/input/2022-ml-project5/train/0464.avi
# /kaggle/input/2022-ml-project5/train/1645.avi
# /kaggle/input/2022-ml-project5/train/0204.avi
# /kaggle/input/2022-ml-project5/train/0346.avi
# /kaggle/input/2022-ml-project5/train/1709.avi
# /kaggle/input/2022-ml-project5/train/1651.avi
# /kaggle/input/2022-ml-project5/train/1547.avi
# /kaggle/input/2022-ml-project5/train/1843.avi
# /kaggle/input/2022-ml-project5/train/1056.avi
# /kaggle/input/2022-ml-project5/train/1418.avi
# /kaggle/input/2022-ml-project5/train/0649.avi
# /kaggle/input/2022-ml-project5/train/1810.avi
# /kaggle/input/2022-ml-project5/train/0560.avi
# /kaggle/input/2022-ml-project5/train/0326.avi
# /kaggle/input/2022-ml-project5/train/1183.avi
# /kaggle/input/2022-ml-project5/train/1511.avi
# /kaggle/input/2022-ml-project5/train/1610.avi
# /kaggle/input/2022-ml-project5/train/0056.avi
# /kaggle/input/2022-ml-project5/train/0462.avi
# /kaggle/input/2022-ml-project5/train/0815.avi
# /kaggle/input/2022-ml-project5/train/1881.avi
# /kaggle/input/2022-ml-project5/train/0130.avi
# /kaggle/input/2022-ml-project5/train/1197.avi
# /kaggle/input/2022-ml-project5/train/0993.avi
# /kaggle/input/2022-ml-project5/train/1335.avi
# /kaggle/input/2022-ml-project5/train/0630.avi
# /kaggle/input/2022-ml-project5/train/0349.avi
# /kaggle/input/2022-ml-project5/train/1950.avi
# /kaggle/input/2022-ml-project5/train/1727.avi
# /kaggle/input/2022-ml-project5/train/0240.avi
# /kaggle/input/2022-ml-project5/train/1800.avi
# /kaggle/input/2022-ml-project5/train/0727.avi
# /kaggle/input/2022-ml-project5/train/1710.avi
# /kaggle/input/2022-ml-project5/train/0831.avi
# /kaggle/input/2022-ml-project5/train/1903.avi
# /kaggle/input/2022-ml-project5/train/1231.avi
# /kaggle/input/2022-ml-project5/train/0980.avi
# /kaggle/input/2022-ml-project5/train/1155.avi
# /kaggle/input/2022-ml-project5/train/1354.avi
# /kaggle/input/2022-ml-project5/train/0037.avi
# /kaggle/input/2022-ml-project5/train/0088.avi
# /kaggle/input/2022-ml-project5/train/1687.avi
# /kaggle/input/2022-ml-project5/train/0196.avi
# /kaggle/input/2022-ml-project5/train/0730.avi
# /kaggle/input/2022-ml-project5/train/0963.avi
# /kaggle/input/2022-ml-project5/train/1909.avi
# /kaggle/input/2022-ml-project5/train/0854.avi
# /kaggle/input/2022-ml-project5/train/0953.avi
# /kaggle/input/2022-ml-project5/train/1031.avi
# /kaggle/input/2022-ml-project5/train/0208.avi
# /kaggle/input/2022-ml-project5/train/0269.avi
# /kaggle/input/2022-ml-project5/train/0496.avi
# /kaggle/input/2022-ml-project5/train/0659.avi
# /kaggle/input/2022-ml-project5/train/1960.avi
# /kaggle/input/2022-ml-project5/train/0267.avi
# /kaggle/input/2022-ml-project5/train/1427.avi
# /kaggle/input/2022-ml-project5/train/1201.avi
# /kaggle/input/2022-ml-project5/train/1376.avi
# /kaggle/input/2022-ml-project5/train/0188.avi
# /kaggle/input/2022-ml-project5/train/1776.avi
# /kaggle/input/2022-ml-project5/train/1276.avi
# /kaggle/input/2022-ml-project5/train/0798.avi
# /kaggle/input/2022-ml-project5/train/0680.avi
# /kaggle/input/2022-ml-project5/train/0824.avi
# /kaggle/input/2022-ml-project5/train/0275.avi
# /kaggle/input/2022-ml-project5/train/0690.avi
# /kaggle/input/2022-ml-project5/train/0359.avi
# /kaggle/input/2022-ml-project5/train/0074.avi
# /kaggle/input/2022-ml-project5/train/1414.avi
# /kaggle/input/2022-ml-project5/train/1971.avi
# /kaggle/input/2022-ml-project5/train/1922.avi
# /kaggle/input/2022-ml-project5/train/1422.avi
# /kaggle/input/2022-ml-project5/train/0936.avi
# /kaggle/input/2022-ml-project5/train/0968.avi
# /kaggle/input/2022-ml-project5/train/1336.avi
# /kaggle/input/2022-ml-project5/train/0362.avi
# /kaggle/input/2022-ml-project5/train/0243.avi
# /kaggle/input/2022-ml-project5/train/1564.avi
# /kaggle/input/2022-ml-project5/train/0530.avi
# /kaggle/input/2022-ml-project5/train/0506.avi
# /kaggle/input/2022-ml-project5/train/0413.avi
# /kaggle/input/2022-ml-project5/train/0499.avi
# /kaggle/input/2022-ml-project5/train/1738.avi
# /kaggle/input/2022-ml-project5/train/1579.avi
# /kaggle/input/2022-ml-project5/train/0177.avi
# /kaggle/input/2022-ml-project5/train/1325.avi
# /kaggle/input/2022-ml-project5/train/1447.avi
# /kaggle/input/2022-ml-project5/train/1920.avi
# /kaggle/input/2022-ml-project5/train/1762.avi
# /kaggle/input/2022-ml-project5/train/1590.avi
# /kaggle/input/2022-ml-project5/train/0790.avi
# /kaggle/input/2022-ml-project5/train/0250.avi
# /kaggle/input/2022-ml-project5/train/0093.avi
# /kaggle/input/2022-ml-project5/train/1112.avi
# /kaggle/input/2022-ml-project5/train/1345.avi
# /kaggle/input/2022-ml-project5/train/1682.avi
# /kaggle/input/2022-ml-project5/train/0591.avi
# /kaggle/input/2022-ml-project5/train/1032.avi
# /kaggle/input/2022-ml-project5/train/0759.avi
# /kaggle/input/2022-ml-project5/train/0465.avi
# /kaggle/input/2022-ml-project5/train/1310.avi
# /kaggle/input/2022-ml-project5/train/1164.avi
# /kaggle/input/2022-ml-project5/train/0098.avi
# /kaggle/input/2022-ml-project5/train/1676.avi
# /kaggle/input/2022-ml-project5/train/1570.avi
# /kaggle/input/2022-ml-project5/train/0057.avi
# /kaggle/input/2022-ml-project5/train/1443.avi
# /kaggle/input/2022-ml-project5/train/0574.avi
# /kaggle/input/2022-ml-project5/train/0114.avi
# /kaggle/input/2022-ml-project5/train/0895.avi
# /kaggle/input/2022-ml-project5/train/0755.avi
# /kaggle/input/2022-ml-project5/train/1020.avi
# /kaggle/input/2022-ml-project5/train/0210.avi
# /kaggle/input/2022-ml-project5/train/1238.avi
# /kaggle/input/2022-ml-project5/train/0433.avi
# /kaggle/input/2022-ml-project5/train/0378.avi
# /kaggle/input/2022-ml-project5/train/1929.avi
# /kaggle/input/2022-ml-project5/train/1246.avi
# /kaggle/input/2022-ml-project5/train/0405.avi
# /kaggle/input/2022-ml-project5/train/1137.avi
# /kaggle/input/2022-ml-project5/train/1052.avi
# /kaggle/input/2022-ml-project5/train/0763.avi
# /kaggle/input/2022-ml-project5/train/0946.avi
# /kaggle/input/2022-ml-project5/train/0872.avi
# /kaggle/input/2022-ml-project5/train/0373.avi
# /kaggle/input/2022-ml-project5/train/1295.avi
# /kaggle/input/2022-ml-project5/train/1864.avi
# /kaggle/input/2022-ml-project5/train/0324.avi
# /kaggle/input/2022-ml-project5/train/0514.avi
# /kaggle/input/2022-ml-project5/train/0375.avi
# /kaggle/input/2022-ml-project5/train/0097.avi
# /kaggle/input/2022-ml-project5/train/1879.avi
# /kaggle/input/2022-ml-project5/train/0972.avi
# /kaggle/input/2022-ml-project5/train/1441.avi
# /kaggle/input/2022-ml-project5/train/1943.avi
# /kaggle/input/2022-ml-project5/train/0623.avi
# /kaggle/input/2022-ml-project5/train/0067.avi
# /kaggle/input/2022-ml-project5/train/0628.avi
# /kaggle/input/2022-ml-project5/train/1555.avi
# /kaggle/input/2022-ml-project5/train/1778.avi
# /kaggle/input/2022-ml-project5/train/1589.avi
# /kaggle/input/2022-ml-project5/train/0118.avi
# /kaggle/input/2022-ml-project5/train/1307.avi
# /kaggle/input/2022-ml-project5/train/0608.avi
# /kaggle/input/2022-ml-project5/train/1254.avi
# /kaggle/input/2022-ml-project5/train/1789.avi
# /kaggle/input/2022-ml-project5/train/1007.avi
# /kaggle/input/2022-ml-project5/train/0751.avi
# /kaggle/input/2022-ml-project5/train/0708.avi
# /kaggle/input/2022-ml-project5/train/1148.avi
# /kaggle/input/2022-ml-project5/train/1856.avi
# /kaggle/input/2022-ml-project5/train/0383.avi
# /kaggle/input/2022-ml-project5/train/1332.avi
# /kaggle/input/2022-ml-project5/train/0091.avi
# /kaggle/input/2022-ml-project5/train/0879.avi
# /kaggle/input/2022-ml-project5/train/1548.avi
# /kaggle/input/2022-ml-project5/train/0080.avi
# /kaggle/input/2022-ml-project5/train/1062.avi
# /kaggle/input/2022-ml-project5/train/1167.avi
# /kaggle/input/2022-ml-project5/train/1121.avi
# /kaggle/input/2022-ml-project5/train/0090.avi
# /kaggle/input/2022-ml-project5/train/0717.avi
# /kaggle/input/2022-ml-project5/train/0859.avi
# /kaggle/input/2022-ml-project5/train/1820.avi
# /kaggle/input/2022-ml-project5/train/0436.avi
# /kaggle/input/2022-ml-project5/train/0857.avi
# /kaggle/input/2022-ml-project5/train/0047.avi
# /kaggle/input/2022-ml-project5/train/1064.avi
# /kaggle/input/2022-ml-project5/train/1421.avi
# /kaggle/input/2022-ml-project5/train/1504.avi
# /kaggle/input/2022-ml-project5/train/0860.avi
# /kaggle/input/2022-ml-project5/train/0132.avi
# /kaggle/input/2022-ml-project5/train/1263.avi
# /kaggle/input/2022-ml-project5/train/0957.avi
# /kaggle/input/2022-ml-project5/train/1534.avi
# /kaggle/input/2022-ml-project5/train/1686.avi
# /kaggle/input/2022-ml-project5/train/0814.avi
# /kaggle/input/2022-ml-project5/train/0449.avi
# /kaggle/input/2022-ml-project5/train/1262.avi
# /kaggle/input/2022-ml-project5/train/1510.avi
# /kaggle/input/2022-ml-project5/train/1657.avi
# /kaggle/input/2022-ml-project5/train/0621.avi
# /kaggle/input/2022-ml-project5/train/0122.avi
# /kaggle/input/2022-ml-project5/train/1108.avi
# /kaggle/input/2022-ml-project5/train/1134.avi
# /kaggle/input/2022-ml-project5/train/1145.avi
# /kaggle/input/2022-ml-project5/train/1213.avi
# /kaggle/input/2022-ml-project5/train/0503.avi
# /kaggle/input/2022-ml-project5/train/1095.avi
# /kaggle/input/2022-ml-project5/train/1328.avi
# /kaggle/input/2022-ml-project5/train/1559.avi
# /kaggle/input/2022-ml-project5/train/0888.avi
# /kaggle/input/2022-ml-project5/train/1488.avi
# /kaggle/input/2022-ml-project5/train/1623.avi
# /kaggle/input/2022-ml-project5/train/0524.avi
# /kaggle/input/2022-ml-project5/train/1857.avi
# /kaggle/input/2022-ml-project5/train/1273.avi
# /kaggle/input/2022-ml-project5/train/0585.avi
# /kaggle/input/2022-ml-project5/train/1935.avi
# /kaggle/input/2022-ml-project5/train/0096.avi
# /kaggle/input/2022-ml-project5/train/0238.avi
# /kaggle/input/2022-ml-project5/train/1470.avi
# /kaggle/input/2022-ml-project5/train/1693.avi
# /kaggle/input/2022-ml-project5/train/1081.avi
# /kaggle/input/2022-ml-project5/train/1514.avi
# /kaggle/input/2022-ml-project5/train/0912.avi
# /kaggle/input/2022-ml-project5/train/0225.avi
# /kaggle/input/2022-ml-project5/train/1182.avi
# /kaggle/input/2022-ml-project5/train/0185.avi
# /kaggle/input/2022-ml-project5/train/0969.avi
# /kaggle/input/2022-ml-project5/train/1053.avi
# /kaggle/input/2022-ml-project5/train/1371.avi
# /kaggle/input/2022-ml-project5/train/1428.avi
# /kaggle/input/2022-ml-project5/train/1311.avi
# /kaggle/input/2022-ml-project5/train/0588.avi
# /kaggle/input/2022-ml-project5/train/0726.avi
# /kaggle/input/2022-ml-project5/train/1080.avi
# /kaggle/input/2022-ml-project5/train/0819.avi
# /kaggle/input/2022-ml-project5/train/1114.avi
# /kaggle/input/2022-ml-project5/train/1225.avi
# /kaggle/input/2022-ml-project5/train/0477.avi
# /kaggle/input/2022-ml-project5/train/1572.avi
# /kaggle/input/2022-ml-project5/train/1093.avi
# /kaggle/input/2022-ml-project5/train/0139.avi
# /kaggle/input/2022-ml-project5/train/1536.avi
# /kaggle/input/2022-ml-project5/train/0575.avi
# /kaggle/input/2022-ml-project5/train/1533.avi
# /kaggle/input/2022-ml-project5/train/1159.avi
# /kaggle/input/2022-ml-project5/train/0785.avi
# /kaggle/input/2022-ml-project5/train/1024.avi
# /kaggle/input/2022-ml-project5/train/1274.avi
# /kaggle/input/2022-ml-project5/train/0505.avi
# /kaggle/input/2022-ml-project5/train/1692.avi
# /kaggle/input/2022-ml-project5/train/1853.avi
# /kaggle/input/2022-ml-project5/train/0222.avi
# /kaggle/input/2022-ml-project5/train/0294.avi
# /kaggle/input/2022-ml-project5/train/1918.avi
# /kaggle/input/2022-ml-project5/train/0742.avi
# /kaggle/input/2022-ml-project5/train/0257.avi
# /kaggle/input/2022-ml-project5/train/0123.avi
# /kaggle/input/2022-ml-project5/train/1575.avi
# /kaggle/input/2022-ml-project5/train/0828.avi
# /kaggle/input/2022-ml-project5/train/1837.avi
# /kaggle/input/2022-ml-project5/train/0181.avi
# /kaggle/input/2022-ml-project5/train/1860.avi
# /kaggle/input/2022-ml-project5/train/0611.avi
# /kaggle/input/2022-ml-project5/train/1925.avi
# /kaggle/input/2022-ml-project5/train/1317.avi
# /kaggle/input/2022-ml-project5/train/1900.avi
# /kaggle/input/2022-ml-project5/train/0915.avi
# /kaggle/input/2022-ml-project5/train/1389.avi
# /kaggle/input/2022-ml-project5/train/1096.avi
# /kaggle/input/2022-ml-project5/train/0806.avi
# /kaggle/input/2022-ml-project5/train/1023.avi
# /kaggle/input/2022-ml-project5/train/0616.avi
# /kaggle/input/2022-ml-project5/train/0200.avi
# /kaggle/input/2022-ml-project5/train/1119.avi
# /kaggle/input/2022-ml-project5/train/1411.avi
# /kaggle/input/2022-ml-project5/train/0494.avi
# /kaggle/input/2022-ml-project5/train/0095.avi
# /kaggle/input/2022-ml-project5/train/0498.avi
# /kaggle/input/2022-ml-project5/train/1296.avi
# /kaggle/input/2022-ml-project5/train/1883.avi
# /kaggle/input/2022-ml-project5/train/1659.avi
# /kaggle/input/2022-ml-project5/train/0904.avi
# /kaggle/input/2022-ml-project5/train/0382.avi
# /kaggle/input/2022-ml-project5/train/0947.avi
# /kaggle/input/2022-ml-project5/train/0108.avi
# /kaggle/input/2022-ml-project5/train/0869.avi
# /kaggle/input/2022-ml-project5/train/0799.avi
# /kaggle/input/2022-ml-project5/train/0194.avi
# /kaggle/input/2022-ml-project5/train/1036.avi
# /kaggle/input/2022-ml-project5/train/1399.avi
# /kaggle/input/2022-ml-project5/train/0901.avi
# /kaggle/input/2022-ml-project5/train/0046.avi
# /kaggle/input/2022-ml-project5/train/1100.avi
# /kaggle/input/2022-ml-project5/train/0217.avi
# /kaggle/input/2022-ml-project5/train/1665.avi
# /kaggle/input/2022-ml-project5/train/1357.avi
# /kaggle/input/2022-ml-project5/train/1002.avi
# /kaggle/input/2022-ml-project5/train/0941.avi
# /kaggle/input/2022-ml-project5/train/0374.avi
# /kaggle/input/2022-ml-project5/train/1558.avi
# /kaggle/input/2022-ml-project5/train/0010.avi
# /kaggle/input/2022-ml-project5/train/1468.avi
# /kaggle/input/2022-ml-project5/train/1374.avi
# /kaggle/input/2022-ml-project5/train/0335.avi
# /kaggle/input/2022-ml-project5/train/1685.avi
# /kaggle/input/2022-ml-project5/train/1400.avi
# /kaggle/input/2022-ml-project5/train/1211.avi
# /kaggle/input/2022-ml-project5/train/1887.avi
# /kaggle/input/2022-ml-project5/train/0696.avi
# /kaggle/input/2022-ml-project5/train/0392.avi
# /kaggle/input/2022-ml-project5/train/1249.avi
# /kaggle/input/2022-ml-project5/train/1941.avi
# /kaggle/input/2022-ml-project5/train/0463.avi
# /kaggle/input/2022-ml-project5/train/0735.avi
# /kaggle/input/2022-ml-project5/train/1602.avi
# /kaggle/input/2022-ml-project5/train/1493.avi
# /kaggle/input/2022-ml-project5/train/0062.avi
# /kaggle/input/2022-ml-project5/train/0385.avi
# /kaggle/input/2022-ml-project5/train/0684.avi
# /kaggle/input/2022-ml-project5/train/1113.avi
# /kaggle/input/2022-ml-project5/train/0801.avi
# /kaggle/input/2022-ml-project5/train/0171.avi
# /kaggle/input/2022-ml-project5/train/1320.avi
# /kaggle/input/2022-ml-project5/train/0952.avi
# /kaggle/input/2022-ml-project5/train/0935.avi
# /kaggle/input/2022-ml-project5/train/0124.avi
# /kaggle/input/2022-ml-project5/train/0389.avi
# /kaggle/input/2022-ml-project5/train/1719.avi
# /kaggle/input/2022-ml-project5/train/1091.avi
# /kaggle/input/2022-ml-project5/train/0148.avi
# /kaggle/input/2022-ml-project5/train/1075.avi
# /kaggle/input/2022-ml-project5/train/0906.avi
# /kaggle/input/2022-ml-project5/train/0893.avi
# /kaggle/input/2022-ml-project5/train/0415.avi
# /kaggle/input/2022-ml-project5/train/1791.avi
# /kaggle/input/2022-ml-project5/train/0537.avi
# /kaggle/input/2022-ml-project5/train/1933.avi
# /kaggle/input/2022-ml-project5/train/0903.avi
# /kaggle/input/2022-ml-project5/train/0271.avi
# /kaggle/input/2022-ml-project5/train/1822.avi
# /kaggle/input/2022-ml-project5/train/0981.avi
# /kaggle/input/2022-ml-project5/train/1131.avi
# /kaggle/input/2022-ml-project5/train/1919.avi
# /kaggle/input/2022-ml-project5/train/0664.avi
# /kaggle/input/2022-ml-project5/train/1725.avi
# /kaggle/input/2022-ml-project5/train/0495.avi
# /kaggle/input/2022-ml-project5/train/1370.avi
# /kaggle/input/2022-ml-project5/train/1156.avi
# /kaggle/input/2022-ml-project5/train/0527.avi
# /kaggle/input/2022-ml-project5/train/1458.avi
# /kaggle/input/2022-ml-project5/train/0393.avi
# /kaggle/input/2022-ml-project5/train/1880.avi
# /kaggle/input/2022-ml-project5/train/1446.avi
# /kaggle/input/2022-ml-project5/train/0356.avi
# /kaggle/input/2022-ml-project5/train/0780.avi
# /kaggle/input/2022-ml-project5/train/1050.avi
# /kaggle/input/2022-ml-project5/train/1768.avi
# /kaggle/input/2022-ml-project5/train/0823.avi
# /kaggle/input/2022-ml-project5/train/0024.avi
# /kaggle/input/2022-ml-project5/train/0691.avi
# /kaggle/input/2022-ml-project5/train/1471.avi
# /kaggle/input/2022-ml-project5/train/0228.avi
# /kaggle/input/2022-ml-project5/train/1006.avi
# /kaggle/input/2022-ml-project5/train/1492.avi
# /kaggle/input/2022-ml-project5/train/0478.avi
# /kaggle/input/2022-ml-project5/train/0409.avi
# /kaggle/input/2022-ml-project5/train/0282.avi
# /kaggle/input/2022-ml-project5/train/0802.avi
# /kaggle/input/2022-ml-project5/train/1171.avi
# /kaggle/input/2022-ml-project5/train/0376.avi
# /kaggle/input/2022-ml-project5/train/1565.avi
# /kaggle/input/2022-ml-project5/train/1520.avi
# /kaggle/input/2022-ml-project5/train/0418.avi
# /kaggle/input/2022-ml-project5/train/0134.avi
# /kaggle/input/2022-ml-project5/train/0855.avi
# /kaggle/input/2022-ml-project5/train/1016.avi
# /kaggle/input/2022-ml-project5/train/1699.avi
# /kaggle/input/2022-ml-project5/train/0234.avi
# /kaggle/input/2022-ml-project5/train/0094.avi
# /kaggle/input/2022-ml-project5/train/1664.avi
# /kaggle/input/2022-ml-project5/train/0187.avi
# /kaggle/input/2022-ml-project5/train/1382.avi
# /kaggle/input/2022-ml-project5/train/0580.avi
# /kaggle/input/2022-ml-project5/train/2019.avi
# /kaggle/input/2022-ml-project5/train/1502.avi
# /kaggle/input/2022-ml-project5/train/1938.avi
# /kaggle/input/2022-ml-project5/train/1946.avi
# /kaggle/input/2022-ml-project5/train/0520.avi
# /kaggle/input/2022-ml-project5/train/0821.avi
# /kaggle/input/2022-ml-project5/train/0847.avi
# /kaggle/input/2022-ml-project5/train/0322.avi
# /kaggle/input/2022-ml-project5/train/0914.avi
# /kaggle/input/2022-ml-project5/train/0565.avi
# /kaggle/input/2022-ml-project5/train/1878.avi
# /kaggle/input/2022-ml-project5/train/1814.avi
# /kaggle/input/2022-ml-project5/train/1783.avi
# /kaggle/input/2022-ml-project5/train/1035.avi
# /kaggle/input/2022-ml-project5/train/0165.avi
# /kaggle/input/2022-ml-project5/train/0388.avi
# /kaggle/input/2022-ml-project5/train/1718.avi
# /kaggle/input/2022-ml-project5/train/1256.avi
# /kaggle/input/2022-ml-project5/train/1285.avi
# /kaggle/input/2022-ml-project5/train/1601.avi
# /kaggle/input/2022-ml-project5/train/1122.avi
# /kaggle/input/2022-ml-project5/train/0703.avi
# /kaggle/input/2022-ml-project5/train/1758.avi
# /kaggle/input/2022-ml-project5/train/0141.avi
# /kaggle/input/2022-ml-project5/train/1339.avi
# /kaggle/input/2022-ml-project5/train/1232.avi
# /kaggle/input/2022-ml-project5/train/0076.avi
# /kaggle/input/2022-ml-project5/train/0635.avi
# /kaggle/input/2022-ml-project5/train/0922.avi
# /kaggle/input/2022-ml-project5/train/0602.avi
# /kaggle/input/2022-ml-project5/train/1130.avi
# /kaggle/input/2022-ml-project5/train/1517.avi
# /kaggle/input/2022-ml-project5/train/0453.avi
# /kaggle/input/2022-ml-project5/train/0302.avi
# /kaggle/input/2022-ml-project5/train/0958.avi
# /kaggle/input/2022-ml-project5/train/0773.avi
# /kaggle/input/2022-ml-project5/train/0381.avi
# /kaggle/input/2022-ml-project5/train/1111.avi
# /kaggle/input/2022-ml-project5/train/0549.avi
# /kaggle/input/2022-ml-project5/train/0667.avi
# /kaggle/input/2022-ml-project5/train/1609.avi
# /kaggle/input/2022-ml-project5/train/0983.avi
# /kaggle/input/2022-ml-project5/train/0367.avi
# /kaggle/input/2022-ml-project5/train/0191.avi
# /kaggle/input/2022-ml-project5/train/0338.avi
# /kaggle/input/2022-ml-project5/train/0031.avi
# /kaggle/input/2022-ml-project5/train/0125.avi
# /kaggle/input/2022-ml-project5/train/0396.avi
# /kaggle/input/2022-ml-project5/train/0321.avi
# /kaggle/input/2022-ml-project5/train/0626.avi
# /kaggle/input/2022-ml-project5/train/0281.avi
# /kaggle/input/2022-ml-project5/train/1478.avi
# /kaggle/input/2022-ml-project5/train/0353.avi
# /kaggle/input/2022-ml-project5/train/0757.avi
# /kaggle/input/2022-ml-project5/train/1677.avi
# /kaggle/input/2022-ml-project5/train/1862.avi
# /kaggle/input/2022-ml-project5/train/0241.avi
# /kaggle/input/2022-ml-project5/train/1037.avi
# /kaggle/input/2022-ml-project5/train/1544.avi
# /kaggle/input/2022-ml-project5/train/1747.avi
# /kaggle/input/2022-ml-project5/train/2010.avi
# /kaggle/input/2022-ml-project5/train/0685.avi
# /kaggle/input/2022-ml-project5/train/1869.avi
# /kaggle/input/2022-ml-project5/train/1116.avi
# /kaggle/input/2022-ml-project5/train/0810.avi
# /kaggle/input/2022-ml-project5/train/1369.avi
# /kaggle/input/2022-ml-project5/train/0874.avi
# /kaggle/input/2022-ml-project5/train/1607.avi
# /kaggle/input/2022-ml-project5/train/1519.avi
# /kaggle/input/2022-ml-project5/train/0488.avi
# /kaggle/input/2022-ml-project5/train/0518.avi
# /kaggle/input/2022-ml-project5/train/0161.avi
# /kaggle/input/2022-ml-project5/train/0129.avi
# /kaggle/input/2022-ml-project5/train/0982.avi
# /kaggle/input/2022-ml-project5/train/1185.avi
# /kaggle/input/2022-ml-project5/train/0259.avi
# /kaggle/input/2022-ml-project5/train/2007.avi
# /kaggle/input/2022-ml-project5/train/0842.avi
# /kaggle/input/2022-ml-project5/train/1505.avi
# /kaggle/input/2022-ml-project5/train/1305.avi
# /kaggle/input/2022-ml-project5/train/1691.avi
# /kaggle/input/2022-ml-project5/train/1060.avi
# /kaggle/input/2022-ml-project5/train/1153.avi
# /kaggle/input/2022-ml-project5/train/0260.avi
# /kaggle/input/2022-ml-project5/train/1952.avi
# /kaggle/input/2022-ml-project5/train/1567.avi
# /kaggle/input/2022-ml-project5/train/1581.avi
# /kaggle/input/2022-ml-project5/train/1598.avi
# /kaggle/input/2022-ml-project5/train/0695.avi
# /kaggle/input/2022-ml-project5/train/0115.avi
# /kaggle/input/2022-ml-project5/train/0931.avi
# /kaggle/input/2022-ml-project5/train/0485.avi
# /kaggle/input/2022-ml-project5/train/0811.avi
# /kaggle/input/2022-ml-project5/train/0563.avi
# /kaggle/input/2022-ml-project5/train/1761.avi
# /kaggle/input/2022-ml-project5/train/1043.avi
# /kaggle/input/2022-ml-project5/train/1746.avi
# /kaggle/input/2022-ml-project5/train/1698.avi
# ...
# /kaggle/input/2022-ml-project5/train/0305.avi
# /kaggle/input/2022-ml-project5/train/1323.avi
# /kaggle/input/2022-ml-project5/train/0797.avi
# /kaggle/input/2022-ml-project5/train/0540.avi
# /kaggle/input/2022-ml-project5/train/0470.avi
# /kaggle/input/2022-ml-project5/train/0227.avi
# /kaggle/input/2022-ml-project5/train/1521.avi
# /kaggle/input/2022-ml-project5/train/1449.avi
# /kaggle/input/2022-ml-project5/train/0315.avi
# /kaggle/input/2022-ml-project5/train/0456.avi
# /kaggle/input/2022-ml-project5/train/1722.avi
# /kaggle/input/2022-ml-project5/train/1344.avi
# /kaggle/input/2022-ml-project5/train/0172.avi
# /kaggle/input/2022-ml-project5/train/1255.avi
# /kaggle/input/2022-ml-project5/train/1629.avi
# /kaggle/input/2022-ml-project5/train/0604.avi
# /kaggle/input/2022-ml-project5/train/1803.avi
# /kaggle/input/2022-ml-project5/train/0858.avi
# /kaggle/input/2022-ml-project5/train/0175.avi
# /kaggle/input/2022-ml-project5/train/0766.avi
# /kaggle/input/2022-ml-project5/train/1566.avi
# /kaggle/input/2022-ml-project5/train/1998.avi
# /kaggle/input/2022-ml-project5/train/0251.avi
# /kaggle/input/2022-ml-project5/train/0758.avi
# /kaggle/input/2022-ml-project5/train/0955.avi
# /kaggle/input/2022-ml-project5/train/0034.avi
# /kaggle/input/2022-ml-project5/train/1269.avi
# /kaggle/input/2022-ml-project5/train/1968.avi
# /kaggle/input/2022-ml-project5/train/1721.avi
# /kaggle/input/2022-ml-project5/train/0701.avi
# /kaggle/input/2022-ml-project5/train/1684.avi
# /kaggle/input/2022-ml-project5/train/1571.avi
# /kaggle/input/2022-ml-project5/train/1073.avi
# /kaggle/input/2022-ml-project5/train/0559.avi
# /kaggle/input/2022-ml-project5/train/1551.avi
# /kaggle/input/2022-ml-project5/train/0918.avi
# /kaggle/input/2022-ml-project5/train/0864.avi
# /kaggle/input/2022-ml-project5/train/1901.avi
# /kaggle/input/2022-ml-project5/train/1127.avi
# /kaggle/input/2022-ml-project5/train/1944.avi
# /kaggle/input/2022-ml-project5/train/1445.avi
# /kaggle/input/2022-ml-project5/train/0542.avi
# /kaggle/input/2022-ml-project5/train/0424.avi
# /kaggle/input/2022-ml-project5/train/1874.avi
# /kaggle/input/2022-ml-project5/train/0881.avi
# /kaggle/input/2022-ml-project5/train/1124.avi
# /kaggle/input/2022-ml-project5/train/1042.avi
# /kaggle/input/2022-ml-project5/train/1059.avi
# /kaggle/input/2022-ml-project5/train/0085.avi
# /kaggle/input/2022-ml-project5/train/1315.avi
# /kaggle/input/2022-ml-project5/train/1104.avi
# /kaggle/input/2022-ml-project5/train/0101.avi
# /kaggle/input/2022-ml-project5/train/2014.avi
# /kaggle/input/2022-ml-project5/train/1010.avi
# /kaggle/input/2022-ml-project5/train/1923.avi
# /kaggle/input/2022-ml-project5/train/0308.avi
# /kaggle/input/2022-ml-project5/train/1054.avi
# /kaggle/input/2022-ml-project5/train/0249.avi
# /kaggle/input/2022-ml-project5/train/0412.avi
# /kaggle/input/2022-ml-project5/train/1214.avi
# /kaggle/input/2022-ml-project5/train/1594.avi
# /kaggle/input/2022-ml-project5/train/1228.avi
# /kaggle/input/2022-ml-project5/train/1796.avi
# /kaggle/input/2022-ml-project5/train/1240.avi
# /kaggle/input/2022-ml-project5/train/1805.avi
# /kaggle/input/2022-ml-project5/train/0547.avi
# /kaggle/input/2022-ml-project5/train/1615.avi
# /kaggle/input/2022-ml-project5/train/0070.avi
# /kaggle/input/2022-ml-project5/train/1086.avi
# /kaggle/input/2022-ml-project5/train/1259.avi
# /kaggle/input/2022-ml-project5/train/1655.avi
# /kaggle/input/2022-ml-project5/train/1646.avi
# /kaggle/input/2022-ml-project5/train/1202.avi
# /kaggle/input/2022-ml-project5/train/1596.avi
# /kaggle/input/2022-ml-project5/train/0934.avi
# /kaggle/input/2022-ml-project5/train/0411.avi
# /kaggle/input/2022-ml-project5/train/2002.avi
# /kaggle/input/2022-ml-project5/train/0674.avi
# /kaggle/input/2022-ml-project5/train/1409.avi
# /kaggle/input/2022-ml-project5/train/0817.avi
# /kaggle/input/2022-ml-project5/train/0829.avi
# /kaggle/input/2022-ml-project5/train/0698.avi
# /kaggle/input/2022-ml-project5/train/1848.avi
# /kaggle/input/2022-ml-project5/train/1373.avi
# /kaggle/input/2022-ml-project5/train/0720.avi
# /kaggle/input/2022-ml-project5/train/1658.avi
# /kaggle/input/2022-ml-project5/train/0073.avi
# /kaggle/input/2022-ml-project5/train/0988.avi
# /kaggle/input/2022-ml-project5/train/1479.avi
# /kaggle/input/2022-ml-project5/train/1380.avi
# /kaggle/input/2022-ml-project5/train/0192.avi
# /kaggle/input/2022-ml-project5/train/1337.avi
# /kaggle/input/2022-ml-project5/train/1894.avi
# /kaggle/input/2022-ml-project5/train/1331.avi
# /kaggle/input/2022-ml-project5/train/0794.avi
# /kaggle/input/2022-ml-project5/train/1423.avi
# /kaggle/input/2022-ml-project5/train/0562.avi
# /kaggle/input/2022-ml-project5/train/0276.avi
# /kaggle/input/2022-ml-project5/train/1621.avi
# /kaggle/input/2022-ml-project5/train/1983.avi
# /kaggle/input/2022-ml-project5/train/1140.avi
# /kaggle/input/2022-ml-project5/train/1973.avi
# /kaggle/input/2022-ml-project5/train/1949.avi
# /kaggle/input/2022-ml-project5/train/1720.avi
# /kaggle/input/2022-ml-project5/train/0437.avi
# /kaggle/input/2022-ml-project5/train/0661.avi
# /kaggle/input/2022-ml-project5/train/0209.avi
# /kaggle/input/2022-ml-project5/train/1772.avi
# /kaggle/input/2022-ml-project5/train/1009.avi
# /kaggle/input/2022-ml-project5/train/1641.avi
# /kaggle/input/2022-ml-project5/train/0850.avi
# /kaggle/input/2022-ml-project5/train/1734.avi
# /kaggle/input/2022-ml-project5/train/0297.avi
# /kaggle/input/2022-ml-project5/train/1387.avi
# /kaggle/input/2022-ml-project5/train/1962.avi
# /kaggle/input/2022-ml-project5/train/1106.avi
# /kaggle/input/2022-ml-project5/train/1543.avi
# /kaggle/input/2022-ml-project5/train/0501.avi
# /kaggle/input/2022-ml-project5/train/0699.avi
# /kaggle/input/2022-ml-project5/train/1047.avi
# /kaggle/input/2022-ml-project5/train/1964.avi
# /kaggle/input/2022-ml-project5/train/1759.avi
# /kaggle/input/2022-ml-project5/train/1491.avi
# /kaggle/input/2022-ml-project5/train/0837.avi
# /kaggle/input/2022-ml-project5/train/0334.avi
# /kaggle/input/2022-ml-project5/train/0985.avi
# /kaggle/input/2022-ml-project5/train/0153.avi
# /kaggle/input/2022-ml-project5/train/0421.avi
# /kaggle/input/2022-ml-project5/train/0030.avi
# /kaggle/input/2022-ml-project5/train/0337.avi
# /kaggle/input/2022-ml-project5/train/0293.avi
# /kaggle/input/2022-ml-project5/train/0746.avi
# /kaggle/input/2022-ml-project5/train/0201.avi
# /kaggle/input/2022-ml-project5/train/0220.avi
# /kaggle/input/2022-ml-project5/train/1538.avi
# /kaggle/input/2022-ml-project5/train/0231.avi
# /kaggle/input/2022-ml-project5/train/0767.avi
# /kaggle/input/2022-ml-project5/train/1561.avi
# /kaggle/input/2022-ml-project5/train/1965.avi
# /kaggle/input/2022-ml-project5/train/1375.avi
# /kaggle/input/2022-ml-project5/train/1352.avi
# /kaggle/input/2022-ml-project5/train/1039.avi
# /kaggle/input/2022-ml-project5/train/0779.avi
# /kaggle/input/2022-ml-project5/train/1291.avi
# /kaggle/input/2022-ml-project5/train/0292.avi
# /kaggle/input/2022-ml-project5/train/0641.avi
# /kaggle/input/2022-ml-project5/train/0820.avi
# /kaggle/input/2022-ml-project5/train/1138.avi
# /kaggle/input/2022-ml-project5/train/1937.avi
# /kaggle/input/2022-ml-project5/train/1299.avi
# /kaggle/input/2022-ml-project5/train/0164.avi
# /kaggle/input/2022-ml-project5/train/1499.avi
# /kaggle/input/2022-ml-project5/train/1429.avi
# /kaggle/input/2022-ml-project5/train/0681.avi
# /kaggle/input/2022-ml-project5/train/1391.avi
# /kaggle/input/2022-ml-project5/train/0221.avi
# /kaggle/input/2022-ml-project5/train/1904.avi
# /kaggle/input/2022-ml-project5/train/0945.avi
# /kaggle/input/2022-ml-project5/train/1636.avi
# /kaggle/input/2022-ml-project5/train/1186.avi
# /kaggle/input/2022-ml-project5/train/1545.avi
# /kaggle/input/2022-ml-project5/train/1390.avi
# /kaggle/input/2022-ml-project5/train/1416.avi
# /kaggle/input/2022-ml-project5/train/1141.avi
# /kaggle/input/2022-ml-project5/train/0871.avi
# /kaggle/input/2022-ml-project5/train/0925.avi
# /kaggle/input/2022-ml-project5/train/1425.avi
# /kaggle/input/2022-ml-project5/train/1128.avi
# /kaggle/input/2022-ml-project5/train/1107.avi
# /kaggle/input/2022-ml-project5/train/0743.avi
# /kaggle/input/2022-ml-project5/train/0060.avi
# /kaggle/input/2022-ml-project5/train/1467.avi
# /kaggle/input/2022-ml-project5/train/1974.avi
# /kaggle/input/2022-ml-project5/train/0038.avi
# /kaggle/input/2022-ml-project5/train/1435.avi
# /kaggle/input/2022-ml-project5/train/0111.avi
# /kaggle/input/2022-ml-project5/train/0069.avi
# /kaggle/input/2022-ml-project5/train/0207.avi
# /kaggle/input/2022-ml-project5/train/0287.avi
# /kaggle/input/2022-ml-project5/train/0290.avi
# /kaggle/input/2022-ml-project5/train/1363.avi
# /kaggle/input/2022-ml-project5/train/0092.avi
# /kaggle/input/2022-ml-project5/train/1440.avi
# /kaggle/input/2022-ml-project5/train/0942.avi
# /kaggle/input/2022-ml-project5/train/0756.avi
# /kaggle/input/2022-ml-project5/train/0807.avi
# /kaggle/input/2022-ml-project5/train/0989.avi
# /kaggle/input/2022-ml-project5/train/0235.avi
# /kaggle/input/2022-ml-project5/train/1117.avi
# /kaggle/input/2022-ml-project5/train/1025.avi
# /kaggle/input/2022-ml-project5/train/0878.avi
# /kaggle/input/2022-ml-project5/train/1487.avi
# /kaggle/input/2022-ml-project5/train/0619.avi
# /kaggle/input/2022-ml-project5/train/0460.avi
# /kaggle/input/2022-ml-project5/train/1936.avi
# /kaggle/input/2022-ml-project5/train/0709.avi
# /kaggle/input/2022-ml-project5/train/0938.avi
# /kaggle/input/2022-ml-project5/train/0731.avi
# /kaggle/input/2022-ml-project5/train/1835.avi
# /kaggle/input/2022-ml-project5/train/1125.avi
# /kaggle/input/2022-ml-project5/train/0059.avi
# /kaggle/input/2022-ml-project5/train/1618.avi
# /kaggle/input/2022-ml-project5/train/0656.avi
# /kaggle/input/2022-ml-project5/train/1309.avi
# /kaggle/input/2022-ml-project5/train/1242.avi
# /kaggle/input/2022-ml-project5/train/0711.avi
# /kaggle/input/2022-ml-project5/train/0926.avi
# /kaggle/input/2022-ml-project5/train/1005.avi
# /kaggle/input/2022-ml-project5/train/1749.avi
# /kaggle/input/2022-ml-project5/train/1981.avi
# /kaggle/input/2022-ml-project5/train/0747.avi
# /kaggle/input/2022-ml-project5/train/1402.avi
# /kaggle/input/2022-ml-project5/train/0861.avi
# /kaggle/input/2022-ml-project5/train/1397.avi
# /kaggle/input/2022-ml-project5/train/1090.avi
# /kaggle/input/2022-ml-project5/train/1455.avi
# /kaggle/input/2022-ml-project5/train/0973.avi
# /kaggle/input/2022-ml-project5/train/1868.avi
# /kaggle/input/2022-ml-project5/train/0669.avi
# /kaggle/input/2022-ml-project5/train/0532.avi
# /kaggle/input/2022-ml-project5/train/1525.avi
# /kaggle/input/2022-ml-project5/train/0929.avi
# /kaggle/input/2022-ml-project5/train/1988.avi
# /kaggle/input/2022-ml-project5/train/0158.avi
# /kaggle/input/2022-ml-project5/train/0897.avi
# /kaggle/input/2022-ml-project5/train/1804.avi
# /kaggle/input/2022-ml-project5/train/0607.avi
# /kaggle/input/2022-ml-project5/train/0014.avi
# /kaggle/input/2022-ml-project5/train/0451.avi
# /kaggle/input/2022-ml-project5/train/1045.avi
# /kaggle/input/2022-ml-project5/train/1683.avi
# /kaggle/input/2022-ml-project5/train/1360.avi
# /kaggle/input/2022-ml-project5/train/1633.avi
# /kaggle/input/2022-ml-project5/train/1350.avi
# /kaggle/input/2022-ml-project5/train/0884.avi
# /kaggle/input/2022-ml-project5/train/1034.avi
# /kaggle/input/2022-ml-project5/train/0629.avi
# /kaggle/input/2022-ml-project5/train/1910.avi
# /kaggle/input/2022-ml-project5/train/1838.avi
# /kaggle/input/2022-ml-project5/train/0541.avi
# /kaggle/input/2022-ml-project5/train/1101.avi
# /kaggle/input/2022-ml-project5/train/1706.avi
# /kaggle/input/2022-ml-project5/train/2012.avi
# /kaggle/input/2022-ml-project5/train/0612.avi
# /kaggle/input/2022-ml-project5/train/0990.avi
# /kaggle/input/2022-ml-project5/train/1630.avi
# /kaggle/input/2022-ml-project5/train/1892.avi
# /kaggle/input/2022-ml-project5/train/0528.avi
# /kaggle/input/2022-ml-project5/train/0529.avi
# /kaggle/input/2022-ml-project5/train/1546.avi
# /kaggle/input/2022-ml-project5/train/1662.avi
# /kaggle/input/2022-ml-project5/train/1793.avi
# /kaggle/input/2022-ml-project5/train/0760.avi
# /kaggle/input/2022-ml-project5/train/2013.avi
# /kaggle/input/2022-ml-project5/train/0245.avi
# /kaggle/input/2022-ml-project5/train/1635.avi
# /kaggle/input/2022-ml-project5/train/1308.avi
# /kaggle/input/2022-ml-project5/train/0550.avi
# /kaggle/input/2022-ml-project5/train/1264.avi
# /kaggle/input/2022-ml-project5/train/1250.avi
# /kaggle/input/2022-ml-project5/train/0355.avi
# /kaggle/input/2022-ml-project5/train/1872.avi
# /kaggle/input/2022-ml-project5/train/0156.avi
# /kaggle/input/2022-ml-project5/train/1523.avi
# /kaggle/input/2022-ml-project5/train/1088.avi
# /kaggle/input/2022-ml-project5/train/1669.avi
# /kaggle/input/2022-ml-project5/train/0976.avi
# /kaggle/input/2022-ml-project5/train/0471.avi
# /kaggle/input/2022-ml-project5/train/0186.avi
# /kaggle/input/2022-ml-project5/train/0329.avi
# /kaggle/input/2022-ml-project5/train/1433.avi
# /kaggle/input/2022-ml-project5/train/0920.avi
# /kaggle/input/2022-ml-project5/train/1410.avi
# /kaggle/input/2022-ml-project5/train/0237.avi
# /kaggle/input/2022-ml-project5/train/0579.avi
# /kaggle/input/2022-ml-project5/train/2018.avi
# /kaggle/input/2022-ml-project5/train/1432.avi
# /kaggle/input/2022-ml-project5/train/1663.avi
# /kaggle/input/2022-ml-project5/train/0716.avi
# /kaggle/input/2022-ml-project5/train/1048.avi
# /kaggle/input/2022-ml-project5/train/1484.avi
# /kaggle/input/2022-ml-project5/train/0423.avi
# /kaggle/input/2022-ml-project5/train/0432.avi
# /kaggle/input/2022-ml-project5/train/0033.avi
# /kaggle/input/2022-ml-project5/train/1407.avi
# /kaggle/input/2022-ml-project5/train/0344.avi
# /kaggle/input/2022-ml-project5/train/1729.avi
# /kaggle/input/2022-ml-project5/train/1154.avi
# /kaggle/input/2022-ml-project5/train/1092.avi
# /kaggle/input/2022-ml-project5/train/1605.avi
# /kaggle/input/2022-ml-project5/train/1708.avi
# /kaggle/input/2022-ml-project5/train/0789.avi
# /kaggle/input/2022-ml-project5/train/1784.avi
# /kaggle/input/2022-ml-project5/train/1408.avi
# /kaggle/input/2022-ml-project5/train/1568.avi
# /kaggle/input/2022-ml-project5/train/1404.avi
# /kaggle/input/2022-ml-project5/train/0138.avi
# /kaggle/input/2022-ml-project5/train/0721.avi
# /kaggle/input/2022-ml-project5/train/0712.avi
# /kaggle/input/2022-ml-project5/train/0082.avi
# /kaggle/input/2022-ml-project5/train/1026.avi
# /kaggle/input/2022-ml-project5/train/0216.avi
# /kaggle/input/2022-ml-project5/train/0970.avi
# /kaggle/input/2022-ml-project5/train/0121.avi
# /kaggle/input/2022-ml-project5/train/0377.avi
# /kaggle/input/2022-ml-project5/train/0636.avi
# /kaggle/input/2022-ml-project5/train/0627.avi
# /kaggle/input/2022-ml-project5/train/0873.avi
# /kaggle/input/2022-ml-project5/train/1041.avi
# /kaggle/input/2022-ml-project5/train/0960.avi
# /kaggle/input/2022-ml-project5/train/1953.avi
# /kaggle/input/2022-ml-project5/train/1896.avi
# /kaggle/input/2022-ml-project5/train/1322.avi
# /kaggle/input/2022-ml-project5/train/1736.avi
# /kaggle/input/2022-ml-project5/train/1466.avi
# /kaggle/input/2022-ml-project5/train/0406.avi
# /kaggle/input/2022-ml-project5/train/1459.avi
# /kaggle/input/2022-ml-project5/train/1911.avi
# /kaggle/input/2022-ml-project5/train/1394.avi
# /kaggle/input/2022-ml-project5/train/1591.avi
# /kaggle/input/2022-ml-project5/train/1396.avi
# /kaggle/input/2022-ml-project5/train/0019.avi
# /kaggle/input/2022-ml-project5/train/0761.avi
# /kaggle/input/2022-ml-project5/train/1970.avi
# /kaggle/input/2022-ml-project5/train/0676.avi
# /kaggle/input/2022-ml-project5/train/1713.avi
# /kaggle/input/2022-ml-project5/train/0020.avi
# /kaggle/input/2022-ml-project5/train/1055.avi
# /kaggle/input/2022-ml-project5/train/0752.avi
# /kaggle/input/2022-ml-project5/train/1381.avi
# /kaggle/input/2022-ml-project5/train/1453.avi
# /kaggle/input/2022-ml-project5/train/0889.avi
# /kaggle/input/2022-ml-project5/train/0390.avi
# /kaggle/input/2022-ml-project5/train/1989.avi
# /kaggle/input/2022-ml-project5/train/1383.avi
# /kaggle/input/2022-ml-project5/train/0554.avi
# /kaggle/input/2022-ml-project5/train/1608.avi
# /kaggle/input/2022-ml-project5/train/0913.avi
# /kaggle/input/2022-ml-project5/train/0744.avi
# /kaggle/input/2022-ml-project5/train/0719.avi
# /kaggle/input/2022-ml-project5/train/0303.avi
# /kaggle/input/2022-ml-project5/train/2005.avi
# /kaggle/input/2022-ml-project5/train/0310.avi
# /kaggle/input/2022-ml-project5/train/1004.avi
# /kaggle/input/2022-ml-project5/train/1379.avi
# /kaggle/input/2022-ml-project5/train/0620.avi
# /kaggle/input/2022-ml-project5/train/1133.avi

# %%
import os
import numpy as np
import pandas as pd
import tqdm
import time
import cv2
import pickle
import torch

from sklearn.cluster import KMeans
from sklearn.cluster import MiniBatchKMeans
from sklearn.svm import SVC
from scipy.stats import mode
from sklearn.decomposition import PCA

# %%
# 베이스라인 달성을 위한 파라미터 제공
arg_img_size = (128, 128)
arg_dense_sift = True
args_local_cluster = 200
args_global_cluster = 200
num_frame = 5

#############################
# VLAD와 BoW 중 어떤 방식을 사용할 지 결정해줍니다.
#############################
args_aggr = "vlad" # or "bow"

pca_vlad = 128

# %% [markdown]
# # 비디오 전처리 및 프레임 별 특징점(visual word) 추출 (Empty Module 1)

# %%
# train 비디오의 행동 분류 label read
root = "/kaggle/input/2022-ml-project5/"
train_csv = os.path.join(root, "train_label.csv")
train_csv = pd.read_csv(train_csv)
train_csv_arr = np.asarray(train_csv)

# 데이터 셋에 존재하는 행동 분류 정보 read
classinfo = os.path.join(root, "class_info.csv")
classinfo = pd.read_csv(classinfo)
classinfo_arr = np.asarray(classinfo)


train_path = os.path.join(root, "train")
test_path = os.path.join(root, "test")

# train 비디오 경로
train_list = os.listdir(train_path)
train_list.sort()
train_list = [os.path.join(train_path, i) for i in train_list]

# test 비디오 경로
test_list = os.listdir(test_path)
test_list.sort()
test_list = [os.path.join(test_path, i) for i in test_list]

# %%
def video_to_frame(video_path, size, num_frame):
    
    #########################################################
    ## 비디오에서 프레임을 추출해주는 함수
    ## 
    ## Input 
    ##     video_path : 한 비디오의 경로
    ##     size : 비디오 내의 프레임을 읽을 때, 원하는 해상도 크기
    ##     num_frames : 한 비디오 내에서 읽을 프레임의 수
    ##
    ## Output
    ##     frames : 읽고 저장한 총 프레임
    #########################################################
    
    cap = cv2.VideoCapture(video_path)
    
    # 한 비디오의 총 프레임 수 반환 및 원하는 프레임 수 많큼 읽기 위해 읽을 프레임의 인덱스 설정
    total_frame = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    sel_ind = np.linspace(0, total_frame-1, num_frame).astype("int")
    
    
    num=0
    frames = []
    for i in range(total_frame):
        
        # 읽을 프레임 인덱스의 경우 프레임 읽어 메모리에 저장, 아닐 경우 지나감
        if i in sel_ind:
            res, frame = cap.read()
            # 원하는 해상도로 조절 및 grayscale로 변환
            frame = cv2.resize(frame, size, interpolation = cv2.INTER_CUBIC)
            frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
            frames.append(frame)
        else:
            res = cap.grab()        
    cap.release()
    frames = np.asarray(frames)

    return frames

# %%
def computeSIFT(data, dense=False):
    
    #########################################################
    ## 비디오 내의 프레임에서 특징점(visual word)을 SIFT or DenseSIFT로 추출해주는 함수
    ## 
    ## Input 
    ##     data : 한 비디오에서 읽고 저장한 프레임
    ##     dense : SIFT or DenseSIFT 사용 여부
    ##
    ## Output
    ##     x : 프레임에 대해 추출된 특징점(visual word), dict 형태 -> x[0]이면 0번째 인덱스 프레임의 특징점(visual word) [n,128] 확인 가능
    #########################################################
    
    x = {}
    for i in range(0, len(data)):
        if dense: # DenseSIFT 추출
            img = data[i]
            step_size = 8
            kp = [cv2.KeyPoint(x, y, step_size) for x in range(0, img.shape[0], step_size) for y in range(0, img.shape[1], step_size)]
         
            
            ####### Empty Module 1 : DenseSIFT ########
            # 기본 SIFT 와 동일하게 정의 
            # 기본 SIFT 에서는 detectAndCompute를 사용했지만 
            # Dense SIFT는 위에서 생성한 keypoint를 사용해 compute 만을 진행 
            #
            # 참고) cv2.SIFT_creat() 함수와 .compute()함수를 이용하여 구현한다.
            ###########################################
            sift = cv2.SIFT_create()
            kp, desc = sift.compute(img, kp)
            #비디오 내의 프레임에서 특징점을 추출해주는 SIFT_create를 사용하였습니다.
            #배열의 데이터를 수동으로 로드하고 새로운 배열를 반환하는 compute함수를 사용하였습니다.
        
        else: # 기본 SIFT 추출
            sift = cv2.SIFT_create()
            img = data[i]
            kp, desc = sift.detectAndCompute(img, None)
        x.update({i : desc})

    return x

# %%
# train 비디오에서 프레임 추출 및 특징점(visual word) 추출, dict 형태로 train_local_desc[비디오 경로]이면 해당하는 비디오에서 추출한 모든 특징점(visual word) 확인 가능
train_local_desc = {}
for vi, vid_path in enumerate(tqdm.tqdm(train_list, desc="Extract {} in train data".format("dsift" if arg_dense_sift else "sift"))):
    curr_frame = video_to_frame(vid_path, arg_img_size, num_frame)
    local_desc = computeSIFT(curr_frame, arg_dense_sift)
    train_local_desc.update({vid_path : local_desc})

# test 비디오에서 프레임 추출 및 특징점(visual word) 추출, dict 형태로 test_local_desc[비디오 경로]이면 해당하는 비디오에서 추출한 모든 특징점(visual word) 확인 가능
test_local_desc = {}
for vi, vid_path in enumerate(tqdm.tqdm(test_list, desc="Extract {} in test data".format("dsift" if arg_dense_sift else "sift"))):
    curr_frame = video_to_frame(vid_path, arg_img_size, num_frame)
    local_desc = computeSIFT(curr_frame, arg_dense_sift)
    test_local_desc.update({vid_path : local_desc})
# Out:
# Extract dsift in train data: 100%|██████████| 2020/2020 [01:55<00:00, 17.45it/s]
# Extract dsift in test data: 100%|██████████| 505/505 [00:28<00:00, 17.42it/s]

# %%
print("\n\nAggregate SIFT descriptor")
start = time.time()


# train 비디오 별로 나눠진 특징점(visual word)들을 [n,128]형태로 모음, 모아진 특징점(visual word)들의 정보(비디오 내의 몇번째 프레임에서 나온 특징점인지)는 
# 같은 인덱스의 train_frame_total에서 확인 가능 및 비디오 내의 특정 프레임에서 나온 특징점(visual word)의 수는 train_local_info에서 확인 가능
train_frame_total = []
train_local_desc_total = []
train_local_info = {}
for k, v in train_local_desc.items():
    for kk, vv in v.items():
        l_num = 0
        if vv is not None:
            train_local_desc_total.extend(vv)
            train_frame_total.extend([k+", "+str(kk)] * len(vv))
            l_num = len(vv)
        train_local_info.update({k+", "+str(kk) : l_num})
train_local_desc_total = np.asarray(train_local_desc_total)
train_frame_total = np.asarray(train_frame_total)


# test 비디오 별로 나눠진 특징점(visual word)들을 [n,128]형태로 모음, 모아진 특징점(visual word)들의 정보(비디오 내의 몇번째 프레임에서 나온 특징점인지)는 
# 같은 인덱스의 test_frame_total에서 확인 가능 및 비디오 내의 특정 프레임에서 나온 특징점(visual word)의 수는 test_local_info에서 확인 가능
test_frame_total = []
test_local_desc_total = []
test_local_info = {}
for k, v in test_local_desc.items():
    for kk, vv in v.items():
        l_num = 0
        if vv is not None:
            test_local_desc_total.extend(vv)
            test_frame_total.extend([k+", "+str(kk)] * len(vv))
            l_num = len(vv)
        test_local_info.update({k+", "+str(kk) : l_num})
test_local_desc_total = np.asarray(test_local_desc_total)
test_frame_total = np.asarray(test_frame_total)


print("\t{:3.2f}s\n\n".format(time.time()-start))
# Out:
# Aggregate SIFT descriptor
# 	3.70s

# %% [markdown]
# # 비디오 feature 기술을 위한 프레임 feature 기술 (Empty Module 2,3,4)

# %%
def clustering(train_desc, test_desc=None, n_clusters=200):
    #########################################################
    ## 모든 특징점들 중, 대표 특징점(codebook)을 선정하는 함수
    ## 
    ## Input 
    ##     train_desc : 모든 train 비디오의 모든 프레임에서 추출한 특징점(visual word)들
    ##     test_desc : 모든 test 비디오의 모든 프레임에서 추출한 특징점(visual word)들
    ##     n_clusters : 대표 특징점(codebook)의 수
    ##
    ## Output
    ##     train_pred : 대표 특징점(codebook)에 대해 train_desc가 할당된 위치
    ##     test_pred : 대표 특징점(codebook)에 대해 train_desc가 할당된 위치
    ##     clusters : 대표 특징점(codebook)
    ##     kmeans : kmeans 인스턴스
    #########################################################
    
    
    ##### Empty Module 2 : 대표 특징점(codebook) 선정 ######
    # 제약 조건 : MiniBatchKMeans 사용, random_state=0 고정
    # sklearn의 MiniBatchKMeans를 활용하여 n_clusters 크기 만큼의 대표 특징점(codebook)을 선정
    ###########################################
    kmeans = MiniBatchKMeans(n_clusters=n_clusters,random_state=0).fit(train_desc)
    clusters = kmeans.cluster_centers_
    #K-평균 군집화를 이용하여 대표 특징점을 선정해 주기 위해서 MiniBatchKMeans를 사용하였고, 대표 특징점을 설정해주기 위해서 cluster_centers_를 사용하였습니다.
    
    train_pred = kmeans.predict(train_desc)
    if test_desc is not None:
        test_pred = kmeans.predict(test_desc)
    else:
        test_pred = None
    return train_pred, test_pred, clusters, kmeans

# %%
# 모든 train 비디오의 모든 프레임에서 추출한 특징점(visual word)들로 대표 특징점(codebook)을 만들고,
# train 비디오의 모든 프레임에서 추출된 특징점(visual word)과 test 비디오의 모든 프레임에서 추출된 특징점(visual word)을 대표 특징점(codebook)에 할당
train_local_alloc, test_local_alloc, local_codebook, local_kmeans = clustering(train_local_desc_total, test_local_desc_total, args_local_cluster)

# %% [markdown]
# ### BoVW (Bag of Visual Word) 및 VLAD (Vector of Locally Aggregated Descriptors)

# %%
def VLAD(X, alloc, centers):
    #########################################################
    ## 이미지 feature인 VLAD feature를 기술하기 위한 함수
    ## 
    ## Input 
    ##     X : 한 프레임의 특징점(visual word)들
    ##     alloc : 한 프레임의 특징점(visual word)들이 대표 특징점(codebook)에 할당된 위치
    ##     centers : 대표 특징점(codebook)
    ##
    ## Output
    ##     V : VLAD feature
    #########################################################
    
    m,d = X.shape
    k = centers.shape[0]
    
    # VLAD feature를 담기 위한 변수
    V=np.zeros([k,d])

    for i in range(k):
        if np.sum(alloc==i)>0:
            ####################### Empty Module 3 : VLAD ########################
            # 이미지에서 추출된 특징점(visual word) X와 이들이 대표 특징점(codebook)으로 할당된 정보 alloc을 이용해,
            # 동일한 대표 특징점(codebook)으로 할당된 특징점(visual word)들의 벡터 합 계산해 V[i]에 저장
            # hint : 바로 위 조건문의 조건 "alloc==i"의 의미를 파악하고 인덱싱에 활용
            ######################################################################
            V[i] = np.sum(X[alloc==i,:]-centers[i],axis=0)
            # 이미지에서 추출된 특징점들과 이들이 대표 특징점으로 할당된 정보를 이용해, 동일한 대표 특징점으로 할당된 특징점들의 벡터 합 계산해 V[i]에 저장하기 위해서 np.sum를 사용했습니다.
    
    # 후처리 과정
    V = V.flatten()
    V = np.sign(V)*np.sqrt(np.abs(V))
    if np.sqrt(np.dot(V,V))!=0:
        V = V/np.sqrt(np.dot(V,V))
    return V


def BoW(alloc, n_cluster):
    #########################################################
    ## 이미지 feature인 BoW feature를 기술하기 위한 함수
    ## 
    ## Input 
    ##     alloc : 한 프레임의 특징점(visual word)들이 대표 특징점(codebook)에 할당된 위치
    ##     n_cluster : 대표 특징점(codebook)의 수
    ##
    ## Output
    ##     V : BoW feature
    #########################################################
    
    ######################### Empty Module 4 : BoW ##########################
    # 이미지에서 추출된 특징점(visual word)이 대표 특징점(codebook)으로 할당된 정보 alloc의 histogram을 계산
    # np.histogram 함수 참고
    #########################################################################
        
    V, _ = np.histogram(alloc,bins=range(n_cluster+1)) #bin = range(n_cluster)로 하면 1~n_clutster-1까지만 나오므로
    #이미지에서 추출된 특징점이 대표 특징점으로 할당된 정보 alloc의 histogram을 계산하기 위해서 np.histogram을 사용했습니다.
    #도수본포 구간을 나타내는 구분은 따로 필요가 없어서 '_'으로 대채했습니다.
    
    return V

# %% [markdown]
# ### 비디오 내 프레임 별로 이미지 feature 기술

# %%
print("\n\nAllocate center & Descript local histogram")
start = time.time()

# Train 비디오 내의 프레임 별로 이미지 feature 기술 -> train_global_desc
# 각 이미지 feature의 정보(속한 비디오 이름, 비디오 내의 인덱스) -> train_global_desc_key
train_global_desc = []
train_global_desc_key = []
vi=0
for k, v in train_local_info.items():
    if v!=0:
        if args_aggr=="bow":            
            hist_desc = BoW(train_local_alloc[vi:vi+v], args_local_cluster)
        elif args_aggr=="vlad":
            hist_desc = VLAD(train_local_desc_total[vi:vi+v], train_local_alloc[vi:vi+v], local_codebook)
        else:
            print("Set the appropriate variable args_aggr!!")
            import pdb; pdb.set_trace()

        vi+=v
        train_global_desc.append(hist_desc)
        train_global_desc_key.append(k)
train_global_desc = np.asarray(train_global_desc)
train_global_desc_key = np.asarray(train_global_desc_key)


# Test 비디오 내의 프레임 별로 이미지 feature 기술 -> test_global_desc
# 각 이미지 feature의 정보(속한 비디오 이름, 비디오 내의 인덱스) -> test_global_desc_key
test_global_desc = []
test_global_desc_key = []
vi=0
for k, v in test_local_info.items():
    if v!=0:
        if args_aggr=="bow":
            hist_desc = BoW(test_local_alloc[vi:vi+v], args_local_cluster)
        elif args_aggr=="vlad":
            hist_desc = VLAD(test_local_desc_total[vi:vi+v], test_local_alloc[vi:vi+v], local_codebook)
        else:
            print("Set the appropriate variable args_aggr!!")
            import pdb; pdb.set_trace()

        vi+=v
        test_global_desc.append(hist_desc)
        test_global_desc_key.append(k)
test_global_desc = np.asarray(test_global_desc)
test_global_desc_key = np.asarray(test_global_desc_key)

print("\t{:3.2f}s\n\n".format(time.time()-start))
# Out:
# Allocate center & Descript local histogram
# 	49.71s

# %%
# VLAD feature의 경우 큰 차원으로 인해 메모리 부족 현상이 발생하므로 PCA를 이용한 차원 축소
if args_aggr=="vlad":
    print("\n\nReduce dim of descriptor of the frames with PCA")
    start = time.time()
    pca = PCA(n_components=pca_vlad, random_state=0)
    pca.fit(train_global_desc)
    train_global_desc = pca.transform(train_global_desc)
    test_global_desc = pca.transform(test_global_desc)
    print("\t{:3.2f}s\n\n".format(time.time()-start))
# Out:
# Reduce dim of descriptor of the frames with PCA
# 	25.94s

# %%
print("\n\nProcessing label")
start = time.time()

# 분류를 위해, 행동 분류에 대한 train 비디오의 각 프레임 별 label 가공
train_global_id = np.array([int(i.split("/")[-1].split(".")[0]) for i in train_global_desc_key])
train_global_label = []
for fid in train_global_id:
    cind = np.where(train_csv_arr[:, 0]==fid)[0]
    clsname = train_csv_arr[cind, 1]
    cinfo_ind = np.where(classinfo_arr[:, 1] == clsname)[0]
    train_global_label.append(classinfo_arr[cinfo_ind, 0].astype("int"))
train_global_label = np.asarray(train_global_label).ravel()

# 분류를 위해, 행동 분류에 대한 test 비디오의 각 프레임 별 id 가공 
test_global_id = np.array([int(i.split("/")[-1].split(".")[0]) for i in test_global_desc_key])

print("\t{:3.2f}s\n\n".format(time.time()-start))
# Out:
# Processing label
# 	0.43s

# %%
def saveFile(predict, predict_id, name, best_params=None):
    #########################################################
    ## 결과를 저장하기 위한 함수
    ## 
    ## Input 
    ##     predict : 모든 test 비디오의 행동 예측 값
    ##     predict_id : 모든 test 비디오의 id
    ##     name : 원하는 저장 파일 이름
    ##     best_params : 원하는 instance 저장 시 사용
    ##
    #########################################################
    
    data = np.concatenate((np.expand_dims(predict_id.astype("str"), axis=1), np.expand_dims(predict.astype("str"), axis=1)), axis=1)
    csv = pd.DataFrame(data, columns=['Id', 'Category'])
    csv.to_csv(name + ".csv", index=False)
    
    if best_params:
        f = open(name + ".pickle", "wb")
        pickle.dump(best_params, f, 2)

# %% [markdown]
# # 비디오의 모든 프레임에서 얻은 feature를 평균내어 비디오 feature 생성 및 분류 (Empty Module 5)

# %%
print("\n\nSVM global averaging in frame")
start = time.time()
#################### Empty Module 5 : SVM (averaging) ######################
# 제약조건 : sklearn의 SVC 사용 및 random_state=0으로 고정
#          베이스라인 파라미터는 defalut 값을 이용하였습니다
# 각 프레임을 나타내는 이미지 feature를 비디오 별로 평균 내어 비디오 feature로 사용
# 비디오 feature로 학습 후, 행동 예측
# hint : 위 셀에서 선언한 train_global_id, train_global_label, test_global_id 및 np.mean() 활용
###########################################################################
train_avg_video_desc = []
train_avg_video_label = []

for i in np.unique(train_global_id):
    tind = np.where(train_global_id==i)[0]
    train_avg_video_desc.append(np.mean(train_global_desc[tind],axis=0))
    train_avg_video_label.append(np.unique(train_global_label[tind]))
train_avg_video_desc = np.asarray(train_avg_video_desc)
train_avg_video_label = np.asarray(train_avg_video_label).ravel()
#각 프레임을 나타내는 이미지 feature를 비디오 별로 평균을 내어 비디오 feature로 사용하기 위해서 해당 for문을 사용했습니다.
#각각의 index들을 작성하기 어려워서 대신 index를 추출해주는 np.where 함수를 사용했습니다.

test_avg_video_desc = []
for i in np.unique(test_global_id):
    tind = np.where(test_global_id==i)[0]
    test_avg_video_desc.append(np.mean(test_global_desc[tind],axis=0))
test_avg_video_desc = np.asarray(test_avg_video_desc)

#각 프레임을 나타내는 이미지 feature를 비디오 별로 평균을 내어 비디오 feature로 사용하기 위해서 해당 for문을 사용했습니다.
#test_data는 y_data가 필요가 없으므로 label 배열을 따로 만들지 않았습니다.

from sklearn.preprocessing import Normalizer
tf = Normalizer()
train_avg_video_descs = tf.fit_transform(train_avg_video_desc)
test_avg_video_descs = tf.transform(test_avg_video_desc)
#데이터를 전처리를 위해서 Normalizer를 사용하니 성능이 소폭 상승했습니다.

model = SVC(random_state=0,C=100).fit(train_avg_video_descs,train_avg_video_label)
svm_predict = model.predict(test_avg_video_descs)
#데이터를 학습하기 위해서 SVC를 사용했고 이를 통해서 결과를 예측했습니다.

saveFile(classinfo_arr[svm_predict][:,1], np.arange(len(test_list)), "svm_global_averaging")
print("\t{:3.2f}s\n\n".format(time.time()-start))
# Out:
# SVM global averaging in frame
# 	0.94s

# %% [markdown]
# # 비디오의 모든 프레임에서 얻은 feature로 분류기를 사용해 예측하고 예측치 중 가장 많은 빈도를 나타낸 행동을 선정 (Empty Module 6)

# %%
print("\n\nSVM global voting in frame")
start = time.time()
############################### Empty Module 6 : SVM (voting) ##################################
# 제약조건 : sklearn의 SVC 사용 및 random_state=0으로 고정
#          베이스라인 파라미터는 defalut 값을 이용하였습니다
# 각 프레임을 나타내는 이미지 feature를 모두 사용해 SVM 학습
# 학습 시, 각 이미지 feature의 label은 해당되는 비디오의 label(행동)로 사용
# 프레임 별로 행동 예측 후, 같은 비디오 내 프레임의 행동 예측 값의 최빈값을 해당 비디오의 행동 예측 값으로 선정***
# hint : 위 셀에서 선언한 train_global_label, test_global_id 및 mode 활용
################################################################################################
model = SVC(random_state=0).fit(train_global_desc,train_global_label)
svm_predict = model.predict(test_global_desc)
svm_predict_vote = []
for i in np.unique(test_global_id):
    tind = np.where(test_global_id==i)[0]
    voted = mode(svm_predict[tind]).mode.item()
    svm_predict_vote.append(voted)
svm_predict_vote = np.asarray(svm_predict_vote)
#각 프레임을 나타내는 이미지 feature을 모두 사용했고 결과를 SVC를 이용하여 예측 후 같은 비디오 내 프레임의 행동 예측 값의 최빈 값을 해당 비디오의 행동 예측 값으로 선정하기 위해서 for문을 작성했습니다.
#최빈값을 추출하기 위해서 mode함수를 사용했습니다.
saveFile(classinfo_arr[svm_predict_vote][:,1], np.arange(len(test_list)), "svm_global_voting")
print("\t{:3.2f}s\n\n".format(time.time()-start))
# Out:
# SVM global voting in frame
# 	26.94s

# %% [markdown]
# # 프레임 feature에서 대표되는 feature를 선정 후 BoW or VLAD 방식으로 비디오 feature를 기술 (Empty Module 7)

# %%
train_global_alloc, test_global_alloc, global_codebook, global_kmeans = clustering(train_global_desc, test_global_desc, args_global_cluster)

# %%
print("\n\nAllocate center & Descript global histogram")
start = time.time()
train_vid_names = np.asarray([i.split(", ")[0] for i in train_global_desc_key])
train_vid_names_u = np.unique(train_vid_names)

# Train 비디오 내 프레임 별로 기술된 이미지 feature를 기반으로 한번 더 기술하여(한번 더 BoW 혹은 VLAD)
# 각 비디오에 대한 비디오 feature 기술
# Empty Module 7과 관련있으며, 5,6과는 무관
train_video_desc = []
train_video_desc_key = []
for vid_name in train_vid_names_u:
    cind = np.where(vid_name==train_vid_names)[0]
    if args_aggr=="bow":
        hist_desc = BoW(train_global_alloc[cind], args_global_cluster)
    elif args_aggr=="vlad":
        hist_desc = VLAD(train_global_desc[cind], train_global_alloc[cind], global_codebook)
    else:
        print("Set the appropriate variable args_aggr!!")
        import pdb; pdb.set_trace()

    train_video_desc.append(hist_desc)
    train_video_desc_key.append(vid_name)
train_video_desc = np.asarray(train_video_desc)
train_video_desc_key = np.asarray(train_video_desc_key)

# Test 비디오 내 프레임 별로 기술된 이미지 feature를 기반으로 한번 더 기술하여(한번 더 BoW 혹은 VLAD)
# 각 비디오에 대한 비디오 feature 기술
# Empty Module 7과 관련있으며, 5,6과는 무관
test_vid_names = np.asarray([i.split(", ")[0] for i in test_global_desc_key])
test_vid_names_u = np.unique(test_vid_names)

test_video_desc = []
test_video_desc_key = []
for vid_name in test_vid_names_u:
    cind = np.where(vid_name==test_vid_names)[0]
    if args_aggr=="bow":
        hist_desc = BoW(test_global_alloc[cind], args_global_cluster)
    elif args_aggr=="vlad":
        hist_desc = VLAD(test_global_desc[cind], test_global_alloc[cind], global_codebook)
    else:
        print("Set the appropriate variable args_aggr!!")
        import pdb; pdb.set_trace()

    test_video_desc.append(hist_desc)
    test_video_desc_key.append(vid_name)
test_video_desc = np.asarray(test_video_desc)
test_video_desc_key = np.asarray(test_video_desc_key)


print("\t{:3.2f}s\n\n".format(time.time()-start))
# Out:
# Allocate center & Descript global histogram
# 	7.58s

# %%
print("\n\nProcessing label")
start = time.time()

# 분류를 위해, 행동 분류에 대한 각 train 비디오 별 label 가공
train_video_id = np.array([int(i.split("/")[-1].split(".")[0]) for i in train_video_desc_key])
train_video_label = []
for fid in train_video_id:
    cind = np.where(train_csv_arr[:, 0]==fid)[0]
    clsname = train_csv_arr[cind, 1]
    cinfo_ind = np.where(classinfo_arr[:, 1] == clsname)[0]
    train_video_label.append(classinfo_arr[cinfo_ind, 0].astype("int"))
train_video_label = np.asarray(train_video_label).ravel()

# 분류를 위해, 행동 분류에 대한 각 test 비디오 별 id 가공
test_video_id = np.array([int(i.split("/")[-1].split(".")[0]) for i in test_video_desc_key])

print("\t{:3.2f}s\n\n".format(time.time()-start))
# Out:
# Processing label
# 	0.09s

# %%
# 이미지 feature에 대해 다시 한번 VLAD feature 기술 방식을 사용하여 video feature를 기술한 경우 큰 차원으로 인해 메모리 부족 현상이 발생하므로 PCA를 이용한 차원 축소
if args_aggr=="vlad":
    print("\n\nReduce dim of descriptor of the frames with PCA")
    start = time.time()
    pca = PCA(n_components=pca_vlad, random_state=0)
    pca.fit(train_video_desc)
    train_video_desc = pca.transform(train_video_desc)
    test_video_desc = pca.transform(test_video_desc)
    print("\t{:3.2f}s\n\n".format(time.time()-start))
# Out:
# Reduce dim of descriptor of the frames with PCA
# 	6.87s

# %%
print("\n\nSVM video descriptor")
start = time.time()
######################## Empty Module 7 : SVM (video feature) ##########################
# 제약조건 : sklearn의 SVC 사용 및 random_state=0으로 고정
#          베이스라인 파라미터는 defalut 값을 이용하였습니다
# 이전 이미지 feature를 기반으로 각 기술방식(BoW, VLAD)을 한번 더 적용해 만든 비디오 feature 사용
# 비디오 feature로 학습 후, 행동 예측
#######################################################################################
model = SVC(random_state=0).fit(train_video_desc,train_video_label)
svm_predict = model.predict(test_video_desc)
#이전 이미지 feature를 기반으로 각 기술방식(BoW, VLAD)을 한번 더 적용해 만든 비디오 feature 사용해서 SVC를 이용하여 결과를 예측했습니다.
saveFile(classinfo_arr[svm_predict][:,1], test_video_id, "svm_video")
print("\t{:3.2f}s\n\n".format(time.time()-start))
# Out:
# SVM video descriptor
# 	0.87s
